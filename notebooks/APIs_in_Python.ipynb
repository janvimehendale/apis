# %% [markdown]
# # Introduction to APIs
#
#
# ### APIs
#
# An Application Programming Interface, or API, is a structured way to retrieve data from a website. An advantage of using APIs over, for example, downloading csv files, is that an API response will come in a structured, predictable format. There are many APIs available, including
# - Government organizations ([US Government](https://www.data.gov/developers/apis))
# - Large companies ([X API](https://developer.x.com/en/docs))
# - News organizations ([NYT API](https://developer.nytimes.com/))
# - And [many more](https://github.com/public-apis/public-apis)
#
# If you type `how to use an api in python` in google, you get back many articles walking through how to use an API. It is a well documented and useful tool to be familiar with.

# %% [markdown]
# We'll be interacting with APIs using HTTP requests. HTTP, or **Hypertext Transfer Protocol** is the foundation for data communication on the world wide web.
#
# It functions as a request/response protocol. The client submits a request to the server and the server returns a response message, which includes a status code indicating success or failure of the request. When navigating the web, your web browser is using HTTP requests to fetch the contents of the websites you are browsing.
#
# To send HTTP requests, we will be using the [_requests_](https://requests.readthedocs.io/en/master/) library.

# %%
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# ## Basic API Usage
#
# Let's start by using the [Cat Fact API](https://catfact.ninja/), an API which provides cat facts and information about cat breeds.
#
# With any API, you should start by inspecting the documentation.

# %% [markdown]
# We will be using the `requests` package to make a `GET` request to an API. GET is used to request data from a specified resource.
#
# When using an API, the first thing we need to know is the expected URL structure.

# %%
endpoint = 'https://catfact.ninja/fact'

response = requests.get(endpoint)

# %% [markdown]
# Let's check the response. If all is well, we should have a 200 response.

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# To access the content of the response, we can look at the `text` attribute.

# %%
response.text
# Out:
# '{"fact":"A female cat is called a queen or a molly.","length":42}'

# %% [markdown]
# For demonstration purposes, let's see what happens when we send an invalid request.

# %%
endpoint = 'https://catfact.ninja/fac'
response = requests.get(endpoint)
response
# Out:
# <Response [404]>

# %% [markdown]
# What if we want to be able to easily change the number that we want to retrieve. For this, we can make use of an f-string.

# %%
max_length = 20

endpoint = f'https://catfact.ninja/fact?max_length={max_length}'

response = requests.get(endpoint)

response.text
# Out:
# '{"fact":"Cats have 3 eyelids.","length":20}'

# %% [markdown]
# However, it will be easier to work with as a json. We can use the `json` method to convert the results to a dictionary.

# %%
res = response.json()
res
# Out:
# {'fact': 'Cats have 3 eyelids.', 'length': 20}

# %% [markdown]
# Then, we can access the individual elements by passing in the correct key.

# %%
res['fact']
# Out:
# 'Cats have 3 eyelids.'

# %% [markdown]
# We can also use a parameters dictionary to specify the max_length.
#
# #### Parameters
#
# Parameters are specific to each API and indicate what information you want back. These can be compared to the various ways you slice a table or df to get just the subset you want. Some parameters are required, others are optional. Always look at the documentation to know what parameters you should include and what are possible values for each one. When using parameters for an API call, you can do the following:
#
# 1. Make an empty dictionary for the `params` variable
# 2. Look at the documentation to know what parameters you should include, add these as **keys** to the dictionary
# 3. Add the appropriate values for each parameter as the **values** for the dictionary

# %%
endpoint = 'https://catfact.ninja/fact'

params = {
    'max_length': '100'
}

response = requests.get(endpoint, params=params)

response.json()
# Out:
# {'fact': 'There are approximately 100 breeds of cat.', 'length': 42}

# %% [markdown]
# ### NASA API and API Keys
#
# Now, let's work with the NASA API: https://api.nasa.gov/
#
# One of the main ways APIs maintain security is by the use of some form of authentication, such as an API key. An API key can be obtained in a number of ways, depending on the API, and is a way for the application to know who you are and provides you secure access to the data.
#
# To work with the NASA API, you'll need to create an API key.
#
# 1. Scroll down and enter your First Name, Last Name, and email to generate an API key
# 2. Copy the API key into the keys.json file.
#
# **DO NOT SHARE YOUR API KEYS OR PUT THEM IN A PUBLIC PLACE LIKE GITHUB**
#
# API keys should be stored securely on your computer and removed from any code or documents you share.

# %% [markdown]
# Now, we can safely load your key into a variable using the json library.

# %%
import json

# %%
with open('keys.json') as fi:
    credentials = json.load(fi)

# %%
api_key = credentials['api_key']

# %% [markdown]
# 1. Look at the different available APIs in the `Browse APIs` tab
# 2. Click on the **Asteroids - NeoWs**
# 3. Under **Neo - Feed**, copy the URL up to the `?`

# %%
endpoint = 'https://api.nasa.gov/neo/rest/v1/feed?'

# %% [markdown]
# Fill in the parameters dictionary below to retrieve information on all NeoWs between January 1, 2022 and January 7, 2022. (Be sure the include your api key as a parameter).

# %%
params = {
    'start_date' : "2022-01-01",
    'end_date' : "2022-01-07",
    'api_key' : api_key
    
}

# %% [markdown]
# You now have all the pieces to make an API request

# %%
response = requests.get(endpoint, params = params)

# %% [markdown]
# See what was saved to `response`

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# This API returns the results as a json, so we'll access them using the `json` method.

# %%
res = response.json()
res
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2022-01-07&end_date=2022-01-13&detailed=false&api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2021-12-26&end_date=2022-01-01&detailed=false&api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2022-01-01&end_date=2022-01-07&detailed=false&api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#  'element_count': 39,
#  'near_earth_objects': {'2022-01-07': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2494697?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '2494697',
#     'neo_reference_id': '2494697',
#     'name': '494697 (2004 SW55)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2494697',
#     'absolute_magnitude_h': 20.77,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1864468183,
#       'estimated_diameter_max': 0.41690776},
#      'meters': {'estimated_diameter_min': 186.44681832,
#       'estimated_diameter_max': 416.9077599521},
#      'miles': {'estimated_diameter_min': 0.1158526459,
#       'estimated_diameter_max': 0.2590543917},
#      'feet': {'estimated_diameter_min': 611.7021794171,
#       'estimated_diameter_max': 1367.8076551614}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 12:09',
#       'epoch_date_close_approach': 1641557340000,
#       'relative_velocity': {'kilometers_per_second': '10.0478001196',
#        'kilometers_per_hour': '36172.0804304837',
#        'miles_per_hour': '22475.9240874858'},
#       'miss_distance': {'astronomical': '0.1338706738',
#        'lunar': '52.0756921082',
#        'kilometers': '20026767.655944806',
#        'miles': '12444056.3828420828'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2496860?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '2496860',
#     'neo_reference_id': '2496860',
#     'name': '496860 (1999 XL136)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2496860',
#     'absolute_magnitude_h': 19.67,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3094246986,
#       'estimated_diameter_max': 0.69189466},
#      'meters': {'estimated_diameter_min': 309.4246986173,
#       'estimated_diameter_max': 691.8946600257},
#      'miles': {'estimated_diameter_min': 0.1922675344,
#       'estimated_diameter_max': 0.4299232768},
#      'feet': {'estimated_diameter_min': 1015.1729282116,
#       'estimated_diameter_max': 2269.9956763987}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 02:07',
#       'epoch_date_close_approach': 1641521220000,
#       'relative_velocity': {'kilometers_per_second': '16.7624360583',
#        'kilometers_per_hour': '60344.7698097014',
#        'miles_per_hour': '37495.8932187003'},
#       'miss_distance': {'astronomical': '0.0895472705',
#        'lunar': '34.8338882245',
#        'kilometers': '13396080.931113835',
#        'miles': '8323938.704427523'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3311963?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3311963',
#     'neo_reference_id': '3311963',
#     'name': '(2006 AL4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3311963',
#     'absolute_magnitude_h': 24.92,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0275775053,
#       'estimated_diameter_max': 0.0616651765},
#      'meters': {'estimated_diameter_min': 27.5775052924,
#       'estimated_diameter_max': 61.6651764838},
#      'miles': {'estimated_diameter_min': 0.017135862,
#       'estimated_diameter_max': 0.0383169524},
#      'feet': {'estimated_diameter_min': 90.4773824637,
#       'estimated_diameter_max': 202.313577615}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 14:45',
#       'epoch_date_close_approach': 1641566700000,
#       'relative_velocity': {'kilometers_per_second': '9.4579600698',
#        'kilometers_per_hour': '34048.6562512758',
#        'miles_per_hour': '21156.510880133'},
#       'miss_distance': {'astronomical': '0.095183198',
#        'lunar': '37.026264022',
#        'kilometers': '14239203.68058826',
#        'miles': '8847830.887747588'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3401388?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3401388',
#     'neo_reference_id': '3401388',
#     'name': '(2008 CO)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3401388',
#     'absolute_magnitude_h': 22.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0802703167,
#       'estimated_diameter_max': 0.1794898848},
#      'meters': {'estimated_diameter_min': 80.2703167283,
#       'estimated_diameter_max': 179.4898847799},
#      'miles': {'estimated_diameter_min': 0.049877647,
#       'estimated_diameter_max': 0.1115298092},
#      'feet': {'estimated_diameter_min': 263.3540659348,
#       'estimated_diameter_max': 588.8775935812}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 07:54',
#       'epoch_date_close_approach': 1641542040000,
#       'relative_velocity': {'kilometers_per_second': '4.4645655825',
#        'kilometers_per_hour': '16072.4360970133',
#        'miles_per_hour': '9986.7867515025'},
#       'miss_distance': {'astronomical': '0.2067861693',
#        'lunar': '80.4398198577',
#        'kilometers': '30934770.472739391',
#        'miles': '19221975.0369339558'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54245585?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '54245585',
#     'neo_reference_id': '54245585',
#     'name': '(2022 CV2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54245585',
#     'absolute_magnitude_h': 22.99,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0670741189,
#       'estimated_diameter_max': 0.1499822895},
#      'meters': {'estimated_diameter_min': 67.0741189325,
#       'estimated_diameter_max': 149.9822894641},
#      'miles': {'estimated_diameter_min': 0.0416779124,
#       'estimated_diameter_max': 0.0931946452},
#      'feet': {'estimated_diameter_min': 220.0594523586,
#       'estimated_diameter_max': 492.0678945652}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 14:20',
#       'epoch_date_close_approach': 1641565200000,
#       'relative_velocity': {'kilometers_per_second': '8.8178282495',
#        'kilometers_per_hour': '31744.1816982311',
#        'miles_per_hour': '19724.6000113259'},
#       'miss_distance': {'astronomical': '0.124719788',
#        'lunar': '48.515997532',
#        'kilometers': '18657814.63165156',
#        'miles': '11593428.417689128'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54247545?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '54247545',
#     'neo_reference_id': '54247545',
#     'name': '(2016 FH60)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54247545',
#     'absolute_magnitude_h': 23.14,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.06259721,
#       'estimated_diameter_max': 0.1399716167},
#      'meters': {'estimated_diameter_min': 62.597209966,
#       'estimated_diameter_max': 139.9716166857},
#      'miles': {'estimated_diameter_min': 0.038896091,
#       'estimated_diameter_max': 0.0869743034},
#      'feet': {'estimated_diameter_min': 205.3714303447,
#       'estimated_diameter_max': 459.2244788871}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 14:19',
#       'epoch_date_close_approach': 1641565140000,
#       'relative_velocity': {'kilometers_per_second': '8.8180100069',
#        'kilometers_per_hour': '31744.8360247963',
#        'miles_per_hour': '19725.0065844074'},
#       'miss_distance': {'astronomical': '0.1247267296',
#        'lunar': '48.5186978144',
#        'kilometers': '18658853.080225952',
#        'miles': '11594073.6797120576'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2022-01-03': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3313974?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3313974',
#     'neo_reference_id': '3313974',
#     'name': '(2006 BV39)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3313974',
#     'absolute_magnitude_h': 29.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0040230458,
#       'estimated_diameter_max': 0.0089958039},
#      'meters': {'estimated_diameter_min': 4.0230457983,
#       'estimated_diameter_max': 8.9958038817},
#      'miles': {'estimated_diameter_min': 0.002499804,
#       'estimated_diameter_max': 0.0055897317},
#      'feet': {'estimated_diameter_min': 13.198969577,
#       'estimated_diameter_max': 29.5137932072}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 18:46',
#       'epoch_date_close_approach': 1641235560000,
#       'relative_velocity': {'kilometers_per_second': '22.7391653876',
#        'kilometers_per_hour': '81860.9953952192',
#        'miles_per_hour': '50865.239055435'},
#       'miss_distance': {'astronomical': '0.4926957707',
#        'lunar': '191.6586548023',
#        'kilometers': '73706237.854728409',
#        'miles': '45798932.4782096842'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3366282?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3366282',
#     'neo_reference_id': '3366282',
#     'name': '(2007 BD)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3366282',
#     'absolute_magnitude_h': 25.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#       'estimated_diameter_max': 0.0494356193},
#      'meters': {'estimated_diameter_min': 22.1082810359,
#       'estimated_diameter_max': 49.435619262},
#      'miles': {'estimated_diameter_min': 0.0137374447,
#       'estimated_diameter_max': 0.0307178602},
#      'feet': {'estimated_diameter_min': 72.5337327539,
#       'estimated_diameter_max': 162.1903570994}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 21:43',
#       'epoch_date_close_approach': 1641246180000,
#       'relative_velocity': {'kilometers_per_second': '19.3262110391',
#        'kilometers_per_hour': '69574.3597407704',
#        'miles_per_hour': '43230.8014733693'},
#       'miss_distance': {'astronomical': '0.3772486341',
#        'lunar': '146.7497186649',
#        'kilometers': '56435592.121769367',
#        'miles': '35067450.8451645846'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2022-01-04': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3555070?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3555070',
#     'neo_reference_id': '3555070',
#     'name': '(2011 AU4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3555070',
#     'absolute_magnitude_h': 25.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0175612318,
#       'estimated_diameter_max': 0.0392681082},
#      'meters': {'estimated_diameter_min': 17.561231848,
#       'estimated_diameter_max': 39.2681081809},
#      'miles': {'estimated_diameter_min': 0.0109120402,
#       'estimated_diameter_max': 0.0244000636},
#      'feet': {'estimated_diameter_min': 57.6155918963,
#       'estimated_diameter_max': 128.8323800441}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-04',
#       'close_approach_date_full': '2022-Jan-04 07:35',
#       'epoch_date_close_approach': 1641281700000,
#       'relative_velocity': {'kilometers_per_second': '13.3437442927',
#        'kilometers_per_hour': '48037.479453581',
#        'miles_per_hour': '29848.6216082543'},
#       'miss_distance': {'astronomical': '0.3426083627',
#        'lunar': '133.2746530903',
#        'kilometers': '51253481.304107449',
#        'miles': '31847436.4971188362'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3595775?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3595775',
#     'neo_reference_id': '3595775',
#     'name': '(2012 AB11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3595775',
#     'absolute_magnitude_h': 22.32,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#       'estimated_diameter_max': 0.2041925905},
#      'meters': {'estimated_diameter_min': 91.3177025518,
#       'estimated_diameter_max': 204.1925904549},
#      'miles': {'estimated_diameter_min': 0.0567421722,
#       'estimated_diameter_max': 0.1268793541},
#      'feet': {'estimated_diameter_min': 299.59877124,
#       'estimated_diameter_max': 669.9232184681}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-04',
#       'close_approach_date_full': '2022-Jan-04 14:14',
#       'epoch_date_close_approach': 1641305640000,
#       'relative_velocity': {'kilometers_per_second': '17.6164585855',
#        'kilometers_per_hour': '63419.2509076765',
#        'miles_per_hour': '39406.2562098282'},
#       'miss_distance': {'astronomical': '0.2383755028',
#        'lunar': '92.7280705892',
#        'kilometers': '35660467.479059036',
#        'miles': '22158386.9934292568'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3671126?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3671126',
#     'neo_reference_id': '3671126',
#     'name': '(2014 JJ55)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3671126',
#     'absolute_magnitude_h': 25.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0231502122,
#       'estimated_diameter_max': 0.0517654482},
#      'meters': {'estimated_diameter_min': 23.150212221,
#       'estimated_diameter_max': 51.7654482198},
#      'miles': {'estimated_diameter_min': 0.0143848705,
#       'estimated_diameter_max': 0.0321655483},
#      'feet': {'estimated_diameter_min': 75.9521422633,
#       'estimated_diameter_max': 169.8341531374}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-04',
#       'close_approach_date_full': '2022-Jan-04 19:50',
#       'epoch_date_close_approach': 1641325800000,
#       'relative_velocity': {'kilometers_per_second': '6.886716818',
#        'kilometers_per_hour': '24792.1805447869',
#        'miles_per_hour': '15404.896850176'},
#       'miss_distance': {'astronomical': '0.1852678346',
#        'lunar': '72.0691876594',
#        'kilometers': '27715673.435672302',
#        'miles': '17221720.8911176876'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3780740?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3780740',
#     'neo_reference_id': '3780740',
#     'name': '(2017 QW1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3780740',
#     'absolute_magnitude_h': 26.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152951935,
#       'estimated_diameter_max': 0.0342010925},
#      'meters': {'estimated_diameter_min': 15.2951935344,
#       'estimated_diameter_max': 34.201092472},
#      'miles': {'estimated_diameter_min': 0.0095039897,
#       'estimated_diameter_max': 0.021251567},
#      'feet': {'estimated_diameter_min': 50.1810827555,
#       'estimated_diameter_max': 112.2083122258}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-04',
#       'close_approach_date_full': '2022-Jan-04 00:29',
#       'epoch_date_close_approach': 1641256140000,
#       'relative_velocity': {'kilometers_per_second': '8.0150396385',
#        'kilometers_per_hour': '28854.1426986551',
#        'miles_per_hour': '17928.8421673949'},
#       'miss_distance': {'astronomical': '0.1371233644',
#        'lunar': '53.3409887516',
#        'kilometers': '20513363.241473828',
#        'miles': '12746412.8592337064'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2668499?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '2668499',
#     'neo_reference_id': '2668499',
#     'name': '668499 (2012 AB11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2668499',
#     'absolute_magnitude_h': 22.32,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#       'estimated_diameter_max': 0.2041925905},
#      'meters': {'estimated_diameter_min': 91.3177025518,
#       'estimated_diameter_max': 204.1925904549},
#      'miles': {'estimated_diameter_min': 0.0567421722,
#       'estimated_diameter_max': 0.1268793541},
#      'feet': {'estimated_diameter_min': 299.59877124,
#       'estimated_diameter_max': 669.9232184681}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-04',
#       'close_approach_date_full': '2022-Jan-04 14:14',
#       'epoch_date_close_approach': 1641305640000,
#       'relative_velocity': {'kilometers_per_second': '17.6164585635',
#        'kilometers_per_hour': '63419.2508286486',
#        'miles_per_hour': '39406.2561607233'},
#       'miss_distance': {'astronomical': '0.2383755028',
#        'lunar': '92.7280705892',
#        'kilometers': '35660467.479059036',
#        'miles': '22158386.9934292568'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2022-01-05': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3365921?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3365921',
#     'neo_reference_id': '3365921',
#     'name': '(2007 AM)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3365921',
#     'absolute_magnitude_h': 21.82,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1149621763,
#       'estimated_diameter_max': 0.257063241},
#      'meters': {'estimated_diameter_min': 114.9621762891,
#       'estimated_diameter_max': 257.0632410238},
#      'miles': {'estimated_diameter_min': 0.0714341624,
#       'estimated_diameter_max': 0.1597316431},
#      'feet': {'estimated_diameter_min': 377.1725064563,
#       'estimated_diameter_max': 843.3833636804}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-05',
#       'close_approach_date_full': '2022-Jan-05 02:20',
#       'epoch_date_close_approach': 1641349200000,
#       'relative_velocity': {'kilometers_per_second': '11.365527618',
#        'kilometers_per_hour': '40915.8994247244',
#        'miles_per_hour': '25423.5487286572'},
#       'miss_distance': {'astronomical': '0.187637158',
#        'lunar': '72.990854462',
#        'kilometers': '28070119.16965346',
#        'miles': '17441963.257439348'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3479014?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3479014',
#     'neo_reference_id': '3479014',
#     'name': '(2009 WM105)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3479014',
#     'absolute_magnitude_h': 23.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0667659413,
#       'estimated_diameter_max': 0.1492931834},
#      'meters': {'estimated_diameter_min': 66.7659413495,
#       'estimated_diameter_max': 149.2931834393},
#      'miles': {'estimated_diameter_min': 0.0414864197,
#       'estimated_diameter_max': 0.0927664547},
#      'feet': {'estimated_diameter_min': 219.0483710172,
#       'estimated_diameter_max': 489.807047955}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-05',
#       'close_approach_date_full': '2022-Jan-05 15:36',
#       'epoch_date_close_approach': 1641396960000,
#       'relative_velocity': {'kilometers_per_second': '9.734200755',
#        'kilometers_per_hour': '35043.1227181288',
#        'miles_per_hour': '21774.4336689395'},
#       'miss_distance': {'astronomical': '0.2314700751',
#        'lunar': '90.0418592139',
#        'kilometers': '34627430.203700037',
#        'miles': '21516487.3958010306'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3702966?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3702966',
#     'neo_reference_id': '3702966',
#     'name': '(2014 YT9)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3702966',
#     'absolute_magnitude_h': 20.59,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2025606009,
#       'estimated_diameter_max': 0.4529392731},
#      'meters': {'estimated_diameter_min': 202.5606008648,
#       'estimated_diameter_max': 452.9392730968},
#      'miles': {'estimated_diameter_min': 0.1258652831,
#       'estimated_diameter_max': 0.2814433291},
#      'feet': {'estimated_diameter_min': 664.5689217411,
#       'estimated_diameter_max': 1486.0212847469}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-05',
#       'close_approach_date_full': '2022-Jan-05 12:45',
#       'epoch_date_close_approach': 1641386700000,
#       'relative_velocity': {'kilometers_per_second': '32.2897570914',
#        'kilometers_per_hour': '116243.1255289547',
#        'miles_per_hour': '72228.9576376996'},
#       'miss_distance': {'astronomical': '0.4768342941',
#        'lunar': '185.4885404049',
#        'kilometers': '71333394.740313567',
#        'miles': '44324516.1365065446'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2022-01-06': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3170204?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3170204',
#     'neo_reference_id': '3170204',
#     'name': '(2003 YS17)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3170204',
#     'absolute_magnitude_h': 21.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1272198785,
#       'estimated_diameter_max': 0.2844722965},
#      'meters': {'estimated_diameter_min': 127.2198785394,
#       'estimated_diameter_max': 284.4722965033},
#      'miles': {'estimated_diameter_min': 0.0790507431,
#       'estimated_diameter_max': 0.1767628354},
#      'feet': {'estimated_diameter_min': 417.3880663071,
#       'estimated_diameter_max': 933.3080892598}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 05:22',
#       'epoch_date_close_approach': 1641446520000,
#       'relative_velocity': {'kilometers_per_second': '18.7190203137',
#        'kilometers_per_hour': '67388.4731294219',
#        'miles_per_hour': '41872.5765397788'},
#       'miss_distance': {'astronomical': '0.2917149523',
#        'lunar': '113.4771164447',
#        'kilometers': '43639935.511231601',
#        'miles': '27116598.5132980538'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3310464?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3310464',
#     'neo_reference_id': '3310464',
#     'name': '(2006 AN)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3310464',
#     'absolute_magnitude_h': 24.36,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0356906927,
#       'estimated_diameter_max': 0.079806815},
#      'meters': {'estimated_diameter_min': 35.690692667,
#       'estimated_diameter_max': 79.8068149676},
#      'miles': {'estimated_diameter_min': 0.0221771614,
#       'estimated_diameter_max': 0.0495896404},
#      'feet': {'estimated_diameter_min': 117.0954521297,
#       'estimated_diameter_max': 261.8333908182}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 00:04',
#       'epoch_date_close_approach': 1641427440000,
#       'relative_velocity': {'kilometers_per_second': '4.6468802954',
#        'kilometers_per_hour': '16728.7690634073',
#        'miles_per_hour': '10394.6065327599'},
#       'miss_distance': {'astronomical': '0.1541403886',
#        'lunar': '59.9606111654',
#        'kilometers': '23059073.815532282',
#        'miles': '14328244.0594662116'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3403506?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3403506',
#     'neo_reference_id': '3403506',
#     'name': '(2008 DJ)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3403506',
#     'absolute_magnitude_h': 20.62,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1997813652,
#       'estimated_diameter_max': 0.4467247133},
#      'meters': {'estimated_diameter_min': 199.78136523,
#       'estimated_diameter_max': 446.7247132921},
#      'miles': {'estimated_diameter_min': 0.1241383467,
#       'estimated_diameter_max': 0.2775817818},
#      'feet': {'estimated_diameter_min': 655.4506943013,
#       'estimated_diameter_max': 1465.6323083572}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 14:26',
#       'epoch_date_close_approach': 1641479160000,
#       'relative_velocity': {'kilometers_per_second': '11.5390104936',
#        'kilometers_per_hour': '41540.4377769334',
#        'miles_per_hour': '25811.6125731173'},
#       'miss_distance': {'astronomical': '0.1701854261',
#        'lunar': '66.2021307529',
#        'kilometers': '25459377.249602407',
#        'miles': '15819723.4525789366'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3441843?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3441843',
#     'neo_reference_id': '3441843',
#     'name': '(2008 YK2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3441843',
#     'absolute_magnitude_h': 19.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3346223745,
#       'estimated_diameter_max': 0.7482383761},
#      'meters': {'estimated_diameter_min': 334.6223744549,
#       'estimated_diameter_max': 748.2383760735},
#      'miles': {'estimated_diameter_min': 0.2079246394,
#       'estimated_diameter_max': 0.464933628},
#      'feet': {'estimated_diameter_min': 1097.8424710066,
#       'estimated_diameter_max': 2454.8503937571}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 12:24',
#       'epoch_date_close_approach': 1641471840000,
#       'relative_velocity': {'kilometers_per_second': '15.102933025',
#        'kilometers_per_hour': '54370.5588900936',
#        'miles_per_hour': '33783.7508836807'},
#       'miss_distance': {'astronomical': '0.2272639708',
#        'lunar': '88.4056846412',
#        'kilometers': '33998205.959422196',
#        'miles': '21125505.5804744648'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3555163?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3555163',
#     'neo_reference_id': '3555163',
#     'name': '(2011 AR26)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3555163',
#     'absolute_magnitude_h': 20.28,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.233644185,
#       'estimated_diameter_max': 0.5224442801},
#      'meters': {'estimated_diameter_min': 233.6441849736,
#       'estimated_diameter_max': 522.4442801486},
#      'miles': {'estimated_diameter_min': 0.1451797209,
#       'estimated_diameter_max': 0.3246317248},
#      'feet': {'estimated_diameter_min': 766.5491878289,
#       'estimated_diameter_max': 1714.0560920828}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 22:35',
#       'epoch_date_close_approach': 1641508500000,
#       'relative_velocity': {'kilometers_per_second': '13.592238999',
#        'kilometers_per_hour': '48932.060396494',
#        'miles_per_hour': '30404.4794169215'},
#       'miss_distance': {'astronomical': '0.4641931866',
#        'lunar': '180.5711495874',
#        'kilometers': '69442311.983872542',
#        'miles': '43149451.8001113996'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3621814?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3621814',
#     'neo_reference_id': '3621814',
#     'name': '(2012 YL7)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3621814',
#     'absolute_magnitude_h': 22.74,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0752583992,
#       'estimated_diameter_max': 0.1682828966},
#      'meters': {'estimated_diameter_min': 75.2583992483,
#       'estimated_diameter_max': 168.2828965971},
#      'miles': {'estimated_diameter_min': 0.0467633868,
#       'estimated_diameter_max': 0.1045661117},
#      'feet': {'estimated_diameter_min': 246.9107665899,
#       'estimated_diameter_max': 552.1092584717}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 21:39',
#       'epoch_date_close_approach': 1641505140000,
#       'relative_velocity': {'kilometers_per_second': '11.0655614218',
#        'kilometers_per_hour': '39836.0211184656',
#        'miles_per_hour': '24752.5543444155'},
#       'miss_distance': {'astronomical': '0.4024854856',
#        'lunar': '156.5668538984',
#        'kilometers': '60210971.351675672',
#        'miles': '37413362.7172493936'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3701710?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3701710',
#     'neo_reference_id': '3701710',
#     'name': '(2014 WF497)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3701710',
#     'absolute_magnitude_h': 20.34,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2272767323,
#       'estimated_diameter_max': 0.5082062231},
#      'meters': {'estimated_diameter_min': 227.2767322847,
#       'estimated_diameter_max': 508.2062230927},
#      'miles': {'estimated_diameter_min': 0.1412231704,
#       'estimated_diameter_max': 0.315784609},
#      'feet': {'estimated_diameter_min': 745.6585943491,
#       'estimated_diameter_max': 1667.3433049715}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 05:06',
#       'epoch_date_close_approach': 1641445560000,
#       'relative_velocity': {'kilometers_per_second': '14.5446943187',
#        'kilometers_per_hour': '52360.899547158',
#        'miles_per_hour': '32535.0267213994'},
#       'miss_distance': {'astronomical': '0.3452040166',
#        'lunar': '134.2843624574',
#        'kilometers': '51641785.598804642',
#        'miles': '32088717.5974903796'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3703059?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3703059',
#     'neo_reference_id': '3703059',
#     'name': '(2014 YE15)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3703059',
#     'absolute_magnitude_h': 28.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0058150704,
#       'estimated_diameter_max': 0.0130028927},
#      'meters': {'estimated_diameter_min': 5.8150703965,
#       'estimated_diameter_max': 13.0028927004},
#      'miles': {'estimated_diameter_min': 0.0036133161,
#       'estimated_diameter_max': 0.0080796204},
#      'feet': {'estimated_diameter_min': 19.0783155595,
#       'estimated_diameter_max': 42.6604104873}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 03:54',
#       'epoch_date_close_approach': 1641441240000,
#       'relative_velocity': {'kilometers_per_second': '6.3796776658',
#        'kilometers_per_hour': '22966.8395969283',
#        'miles_per_hour': '14270.700970658'},
#       'miss_distance': {'astronomical': '0.0494909337',
#        'lunar': '19.2519732093',
#        'kilometers': '7403738.265831219',
#        'miles': '4600469.6317760622'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3786458?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3786458',
#     'neo_reference_id': '3786458',
#     'name': '(2017 UG)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3786458',
#     'absolute_magnitude_h': 27.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.008405334,
#       'estimated_diameter_max': 0.0187948982},
#      'meters': {'estimated_diameter_min': 8.4053340207,
#       'estimated_diameter_max': 18.7948982439},
#      'miles': {'estimated_diameter_min': 0.0052228308,
#       'estimated_diameter_max': 0.0116786047},
#      'feet': {'estimated_diameter_min': 27.5765560686,
#       'estimated_diameter_max': 61.6630539546}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-06',
#       'close_approach_date_full': '2022-Jan-06 14:15',
#       'epoch_date_close_approach': 1641478500000,
#       'relative_velocity': {'kilometers_per_second': '10.2843834093',
#        'kilometers_per_hour': '37023.780273547',
#        'miles_per_hour': '23005.1372483048'},
#       'miss_distance': {'astronomical': '0.318157399',
#        'lunar': '123.763228211',
#        'kilometers': '47595669.21514013',
#        'miles': '29574577.458908594'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2022-01-01': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2363505?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '2363505',
#     'neo_reference_id': '2363505',
#     'name': '363505 (2003 UC20)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2363505',
#     'absolute_magnitude_h': 18.47,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.5377184977,
#       'estimated_diameter_max': 1.2023751136},
#      'meters': {'estimated_diameter_min': 537.7184976927,
#       'estimated_diameter_max': 1202.3751135999},
#      'miles': {'estimated_diameter_min': 0.3341226806,
#       'estimated_diameter_max': 0.7471210267},
#      'feet': {'estimated_diameter_min': 1764.1683559701,
#       'estimated_diameter_max': 3944.8003677031}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 01:25',
#       'epoch_date_close_approach': 1641000300000,
#       'relative_velocity': {'kilometers_per_second': '12.5185405816',
#        'kilometers_per_hour': '45066.7460938774',
#        'miles_per_hour': '28002.723427054'},
#       'miss_distance': {'astronomical': '0.1576979316',
#        'lunar': '61.3444953924',
#        'kilometers': '23591274.670765692',
#        'miles': '14658938.3364108696'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2488490?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '2488490',
#     'neo_reference_id': '2488490',
#     'name': '488490 (2000 AF205)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2488490',
#     'absolute_magnitude_h': 21.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1108038821,
#       'estimated_diameter_max': 0.2477650126},
#      'meters': {'estimated_diameter_min': 110.8038821264,
#       'estimated_diameter_max': 247.7650126055},
#      'miles': {'estimated_diameter_min': 0.068850319,
#       'estimated_diameter_max': 0.1539539936},
#      'feet': {'estimated_diameter_min': 363.5298086356,
#       'estimated_diameter_max': 812.8773639568}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 15:49',
#       'epoch_date_close_approach': 1641052140000,
#       'relative_velocity': {'kilometers_per_second': '21.0773993912',
#        'kilometers_per_hour': '75878.6378083358',
#        'miles_per_hour': '47148.0346981851'},
#       'miss_distance': {'astronomical': '0.4071860722',
#        'lunar': '158.3953820858',
#        'kilometers': '60914169.094786214',
#        'miles': '37850309.5333251932'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3388081?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3388081',
#     'neo_reference_id': '3388081',
#     'name': '(2007 TL23)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3388081',
#     'absolute_magnitude_h': 21.48,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1344481952,
#       'estimated_diameter_max': 0.3006353038},
#      'meters': {'estimated_diameter_min': 134.4481951604,
#       'estimated_diameter_max': 300.6353038309},
#      'miles': {'estimated_diameter_min': 0.0835422095,
#       'estimated_diameter_max': 0.1868060594},
#      'feet': {'estimated_diameter_min': 441.1030166101,
#       'estimated_diameter_max': 986.3363302205}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 17:46',
#       'epoch_date_close_approach': 1641059160000,
#       'relative_velocity': {'kilometers_per_second': '31.1009901975',
#        'kilometers_per_hour': '111963.5647109464',
#        'miles_per_hour': '69569.8049727544'},
#       'miss_distance': {'astronomical': '0.1976817951',
#        'lunar': '76.8982182939',
#        'kilometers': '29572775.484736437',
#        'miles': '18375670.5950473506'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3592308?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3592308',
#     'neo_reference_id': '3592308',
#     'name': '(2012 AP10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3592308',
#     'absolute_magnitude_h': 26.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0133215567,
#       'estimated_diameter_max': 0.0297879063},
#      'meters': {'estimated_diameter_min': 13.3215566698,
#       'estimated_diameter_max': 29.7879062798},
#      'miles': {'estimated_diameter_min': 0.008277629,
#       'estimated_diameter_max': 0.0185093411},
#      'feet': {'estimated_diameter_min': 43.7058959846,
#       'estimated_diameter_max': 97.7293544391}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 18:51',
#       'epoch_date_close_approach': 1641063060000,
#       'relative_velocity': {'kilometers_per_second': '15.9959341425',
#        'kilometers_per_hour': '57585.3629130324',
#        'miles_per_hour': '35781.3050833784'},
#       'miss_distance': {'astronomical': '0.3971181533',
#        'lunar': '154.4789616337',
#        'kilometers': '59408029.872013471',
#        'miles': '36914438.0172330598'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3744561?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3744561',
#     'neo_reference_id': '3744561',
#     'name': '(2016 CN248)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3744561',
#     'absolute_magnitude_h': 27.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0092162655,
#       'estimated_diameter_max': 0.0206081961},
#      'meters': {'estimated_diameter_min': 9.216265485,
#       'estimated_diameter_max': 20.6081961232},
#      'miles': {'estimated_diameter_min': 0.0057267201,
#       'estimated_diameter_max': 0.0128053354},
#      'feet': {'estimated_diameter_min': 30.2370924539,
#       'estimated_diameter_max': 67.6121941689}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 20:11',
#       'epoch_date_close_approach': 1641067860000,
#       'relative_velocity': {'kilometers_per_second': '10.6983078965',
#        'kilometers_per_hour': '38513.9084274605',
#        'miles_per_hour': '23931.0449337184'},
#       'miss_distance': {'astronomical': '0.4066875807',
#        'lunar': '158.2014688923',
#        'kilometers': '60839595.828173109',
#        'miles': '37803971.8541585442'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3771592?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3771592',
#     'neo_reference_id': '3771592',
#     'name': '(2017 DA120)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3771592',
#     'absolute_magnitude_h': 19.61,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3180936332,
#       'estimated_diameter_max': 0.7112789871},
#      'meters': {'estimated_diameter_min': 318.0936332215,
#       'estimated_diameter_max': 711.2789870931},
#      'miles': {'estimated_diameter_min': 0.197654159,
#       'estimated_diameter_max': 0.4419681355},
#      'feet': {'estimated_diameter_min': 1043.6143156183,
#       'estimated_diameter_max': 2333.5925520145}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 01:31',
#       'epoch_date_close_approach': 1641000660000,
#       'relative_velocity': {'kilometers_per_second': '18.5787910301',
#        'kilometers_per_hour': '66883.6477083809',
#        'miles_per_hour': '41558.8976552437'},
#       'miss_distance': {'astronomical': '0.4700557324',
#        'lunar': '182.8516799036',
#        'kilometers': '70319336.348329988',
#        'miles': '43694409.4701623144'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3775153?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3775153',
#     'neo_reference_id': '3775153',
#     'name': '(2017 KU34)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3775153',
#     'absolute_magnitude_h': 23.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0506471459,
#       'estimated_diameter_max': 0.1132504611},
#      'meters': {'estimated_diameter_min': 50.6471458835,
#       'estimated_diameter_max': 113.2504610618},
#      'miles': {'estimated_diameter_min': 0.0314706677,
#       'estimated_diameter_max': 0.0703705522},
#      'feet': {'estimated_diameter_min': 166.1651821003,
#       'estimated_diameter_max': 371.5566426699}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 18:25',
#       'epoch_date_close_approach': 1641061500000,
#       'relative_velocity': {'kilometers_per_second': '10.1460896076',
#        'kilometers_per_hour': '36525.9225873848',
#        'miles_per_hour': '22695.7878432559'},
#       'miss_distance': {'astronomical': '0.1833710837',
#        'lunar': '71.3313515593',
#        'kilometers': '27431923.541111719',
#        'miles': '17045406.8824269622'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3795123?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3795123',
#     'neo_reference_id': '3795123',
#     'name': '(2017 YK7)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3795123',
#     'absolute_magnitude_h': 24.56,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0325502986,
#       'estimated_diameter_max': 0.0727846803},
#      'meters': {'estimated_diameter_min': 32.5502985765,
#       'estimated_diameter_max': 72.7846803049},
#      'miles': {'estimated_diameter_min': 0.0202258116,
#       'estimated_diameter_max': 0.0452262896},
#      'feet': {'estimated_diameter_min': 106.7923215816,
#       'estimated_diameter_max': 238.7948905315}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 18:10',
#       'epoch_date_close_approach': 1641060600000,
#       'relative_velocity': {'kilometers_per_second': '21.9952907107',
#        'kilometers_per_hour': '79183.0465586744',
#        'miles_per_hour': '49201.2657908608'},
#       'miss_distance': {'astronomical': '0.3664586392',
#        'lunar': '142.5524106488',
#        'kilometers': '54821431.867418504',
#        'miles': '34064458.1724991952'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3825582?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3825582',
#     'neo_reference_id': '3825582',
#     'name': '(2018 NQ1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3825582',
#     'absolute_magnitude_h': 25.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0253837029,
#       'estimated_diameter_max': 0.0567596853},
#      'meters': {'estimated_diameter_min': 25.3837029364,
#       'estimated_diameter_max': 56.7596852866},
#      'miles': {'estimated_diameter_min': 0.0157726969,
#       'estimated_diameter_max': 0.0352688224},
#      'feet': {'estimated_diameter_min': 83.279867942,
#       'estimated_diameter_max': 186.2194458756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 23:29',
#       'epoch_date_close_approach': 1641079740000,
#       'relative_velocity': {'kilometers_per_second': '7.8010080242',
#        'kilometers_per_hour': '28083.6288870371',
#        'miles_per_hour': '17450.0748492814'},
#       'miss_distance': {'astronomical': '0.4642049559',
#        'lunar': '180.5757278451',
#        'kilometers': '69444072.646083933',
#        'miles': '43150545.8248789554'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54248460?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '54248460',
#     'neo_reference_id': '54248460',
#     'name': '(2022 DE2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54248460',
#     'absolute_magnitude_h': 19.57,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3240074354,
#       'estimated_diameter_max': 0.7245026508},
#      'meters': {'estimated_diameter_min': 324.0074353942,
#       'estimated_diameter_max': 724.5026507569},
#      'miles': {'estimated_diameter_min': 0.2013288241,
#       'estimated_diameter_max': 0.4501849366},
#      'feet': {'estimated_diameter_min': 1063.0165543388,
#       'estimated_diameter_max': 2376.9772767092}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-01',
#       'close_approach_date_full': '2022-Jan-01 01:39',
#       'epoch_date_close_approach': 1641001140000,
#       'relative_velocity': {'kilometers_per_second': '18.5807868886',
#        'kilometers_per_hour': '66890.8327988686',
#        'miles_per_hour': '41563.3621910525'},
#       'miss_distance': {'astronomical': '0.4700503163',
#        'lunar': '182.8495730407',
#        'kilometers': '70318526.111306281',
#        'miles': '43693906.0122214378'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2022-01-02': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3625335?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3625335',
#     'neo_reference_id': '3625335',
#     'name': '(2013 BC70)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3625335',
#     'absolute_magnitude_h': 24.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.040230458,
#       'estimated_diameter_max': 0.0899580388},
#      'meters': {'estimated_diameter_min': 40.2304579834,
#       'estimated_diameter_max': 89.9580388169},
#      'miles': {'estimated_diameter_min': 0.0249980399,
#       'estimated_diameter_max': 0.0558973165},
#      'feet': {'estimated_diameter_min': 131.9896957704,
#       'estimated_diameter_max': 295.1379320721}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 04:13',
#       'epoch_date_close_approach': 1641096780000,
#       'relative_velocity': {'kilometers_per_second': '10.1548261794',
#        'kilometers_per_hour': '36557.3742457644',
#        'miles_per_hour': '22715.3306806529'},
#       'miss_distance': {'astronomical': '0.1416245844',
#        'lunar': '55.0919633316',
#        'kilometers': '21186736.165875228',
#        'miles': '13164827.3923170264'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3753290?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3753290',
#     'neo_reference_id': '3753290',
#     'name': '(2016 JT28)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3753290',
#     'absolute_magnitude_h': 23.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0483676488,
#       'estimated_diameter_max': 0.1081533507},
#      'meters': {'estimated_diameter_min': 48.3676488219,
#       'estimated_diameter_max': 108.1533506775},
#      'miles': {'estimated_diameter_min': 0.0300542543,
#       'estimated_diameter_max': 0.0672033557},
#      'feet': {'estimated_diameter_min': 158.6865169607,
#       'estimated_diameter_max': 354.8338390368}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 02:29',
#       'epoch_date_close_approach': 1641090540000,
#       'relative_velocity': {'kilometers_per_second': '13.5100245697',
#        'kilometers_per_hour': '48636.0884509632',
#        'miles_per_hour': '30220.5739599888'},
#       'miss_distance': {'astronomical': '0.1726248284',
#        'lunar': '67.1510582476',
#        'kilometers': '25824306.637755508',
#        'miles': '16046480.0595336904'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3756934?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3756934',
#     'neo_reference_id': '3756934',
#     'name': '(2016 PC2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3756934',
#     'absolute_magnitude_h': 23.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0667659413,
#       'estimated_diameter_max': 0.1492931834},
#      'meters': {'estimated_diameter_min': 66.7659413495,
#       'estimated_diameter_max': 149.2931834393},
#      'miles': {'estimated_diameter_min': 0.0414864197,
#       'estimated_diameter_max': 0.0927664547},
#      'feet': {'estimated_diameter_min': 219.0483710172,
#       'estimated_diameter_max': 489.807047955}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 05:02',
#       'epoch_date_close_approach': 1641099720000,
#       'relative_velocity': {'kilometers_per_second': '20.4077209528',
#        'kilometers_per_hour': '73467.7954302229',
#        'miles_per_hour': '45650.0309994071'},
#       'miss_distance': {'astronomical': '0.495238863',
#        'lunar': '192.647917707',
#        'kilometers': '74086679.04602181',
#        'miles': '46035327.672688578'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3826839?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#     'id': '3826839',
#     'neo_reference_id': '3826839',
#     'name': '(2018 PR23)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3826839',
#     'absolute_magnitude_h': 25.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#       'estimated_diameter_max': 0.0494356193},
#      'meters': {'estimated_diameter_min': 22.1082810359,
#       'estimated_diameter_max': 49.435619262},
#      'miles': {'estimated_diameter_min': 0.0137374447,
#       'estimated_diameter_max': 0.0307178602},
#      'feet': {'estimated_diameter_min': 72.5337327539,
#       'estimated_diameter_max': 162.1903570994}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 02:04',
#       'epoch_date_close_approach': 1641089040000,
#       'relative_velocity': {'kilometers_per_second': '8.4332699552',
#        'kilometers_per_hour': '30359.7718385923',
#        'miles_per_hour': '18864.3815627076'},
#       'miss_distance': {'astronomical': '0.4832391866',
#        'lunar': '187.9800435874',
#        'kilometers': '72291553.015892542',
#        'miles': '44919888.0811873996'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %%
res.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %% [markdown]
# The information that we're interested in is located under `near_earth_objects`.

# %%
res['near_earth_objects']
# Out:
# {'2022-01-07': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2494697?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '2494697',
#    'neo_reference_id': '2494697',
#    'name': '494697 (2004 SW55)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2494697',
#    'absolute_magnitude_h': 20.77,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1864468183,
#      'estimated_diameter_max': 0.41690776},
#     'meters': {'estimated_diameter_min': 186.44681832,
#      'estimated_diameter_max': 416.9077599521},
#     'miles': {'estimated_diameter_min': 0.1158526459,
#      'estimated_diameter_max': 0.2590543917},
#     'feet': {'estimated_diameter_min': 611.7021794171,
#      'estimated_diameter_max': 1367.8076551614}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 12:09',
#      'epoch_date_close_approach': 1641557340000,
#      'relative_velocity': {'kilometers_per_second': '10.0478001196',
#       'kilometers_per_hour': '36172.0804304837',
#       'miles_per_hour': '22475.9240874858'},
#      'miss_distance': {'astronomical': '0.1338706738',
#       'lunar': '52.0756921082',
#       'kilometers': '20026767.655944806',
#       'miles': '12444056.3828420828'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2496860?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '2496860',
#    'neo_reference_id': '2496860',
#    'name': '496860 (1999 XL136)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2496860',
#    'absolute_magnitude_h': 19.67,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3094246986,
#      'estimated_diameter_max': 0.69189466},
#     'meters': {'estimated_diameter_min': 309.4246986173,
#      'estimated_diameter_max': 691.8946600257},
#     'miles': {'estimated_diameter_min': 0.1922675344,
#      'estimated_diameter_max': 0.4299232768},
#     'feet': {'estimated_diameter_min': 1015.1729282116,
#      'estimated_diameter_max': 2269.9956763987}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 02:07',
#      'epoch_date_close_approach': 1641521220000,
#      'relative_velocity': {'kilometers_per_second': '16.7624360583',
#       'kilometers_per_hour': '60344.7698097014',
#       'miles_per_hour': '37495.8932187003'},
#      'miss_distance': {'astronomical': '0.0895472705',
#       'lunar': '34.8338882245',
#       'kilometers': '13396080.931113835',
#       'miles': '8323938.704427523'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3311963?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3311963',
#    'neo_reference_id': '3311963',
#    'name': '(2006 AL4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3311963',
#    'absolute_magnitude_h': 24.92,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0275775053,
#      'estimated_diameter_max': 0.0616651765},
#     'meters': {'estimated_diameter_min': 27.5775052924,
#      'estimated_diameter_max': 61.6651764838},
#     'miles': {'estimated_diameter_min': 0.017135862,
#      'estimated_diameter_max': 0.0383169524},
#     'feet': {'estimated_diameter_min': 90.4773824637,
#      'estimated_diameter_max': 202.313577615}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 14:45',
#      'epoch_date_close_approach': 1641566700000,
#      'relative_velocity': {'kilometers_per_second': '9.4579600698',
#       'kilometers_per_hour': '34048.6562512758',
#       'miles_per_hour': '21156.510880133'},
#      'miss_distance': {'astronomical': '0.095183198',
#       'lunar': '37.026264022',
#       'kilometers': '14239203.68058826',
#       'miles': '8847830.887747588'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3401388?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3401388',
#    'neo_reference_id': '3401388',
#    'name': '(2008 CO)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3401388',
#    'absolute_magnitude_h': 22.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0802703167,
#      'estimated_diameter_max': 0.1794898848},
#     'meters': {'estimated_diameter_min': 80.2703167283,
#      'estimated_diameter_max': 179.4898847799},
#     'miles': {'estimated_diameter_min': 0.049877647,
#      'estimated_diameter_max': 0.1115298092},
#     'feet': {'estimated_diameter_min': 263.3540659348,
#      'estimated_diameter_max': 588.8775935812}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 07:54',
#      'epoch_date_close_approach': 1641542040000,
#      'relative_velocity': {'kilometers_per_second': '4.4645655825',
#       'kilometers_per_hour': '16072.4360970133',
#       'miles_per_hour': '9986.7867515025'},
#      'miss_distance': {'astronomical': '0.2067861693',
#       'lunar': '80.4398198577',
#       'kilometers': '30934770.472739391',
#       'miles': '19221975.0369339558'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54245585?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '54245585',
#    'neo_reference_id': '54245585',
#    'name': '(2022 CV2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54245585',
#    'absolute_magnitude_h': 22.99,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0670741189,
#      'estimated_diameter_max': 0.1499822895},
#     'meters': {'estimated_diameter_min': 67.0741189325,
#      'estimated_diameter_max': 149.9822894641},
#     'miles': {'estimated_diameter_min': 0.0416779124,
#      'estimated_diameter_max': 0.0931946452},
#     'feet': {'estimated_diameter_min': 220.0594523586,
#      'estimated_diameter_max': 492.0678945652}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 14:20',
#      'epoch_date_close_approach': 1641565200000,
#      'relative_velocity': {'kilometers_per_second': '8.8178282495',
#       'kilometers_per_hour': '31744.1816982311',
#       'miles_per_hour': '19724.6000113259'},
#      'miss_distance': {'astronomical': '0.124719788',
#       'lunar': '48.515997532',
#       'kilometers': '18657814.63165156',
#       'miles': '11593428.417689128'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54247545?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '54247545',
#    'neo_reference_id': '54247545',
#    'name': '(2016 FH60)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54247545',
#    'absolute_magnitude_h': 23.14,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.06259721,
#      'estimated_diameter_max': 0.1399716167},
#     'meters': {'estimated_diameter_min': 62.597209966,
#      'estimated_diameter_max': 139.9716166857},
#     'miles': {'estimated_diameter_min': 0.038896091,
#      'estimated_diameter_max': 0.0869743034},
#     'feet': {'estimated_diameter_min': 205.3714303447,
#      'estimated_diameter_max': 459.2244788871}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 14:19',
#      'epoch_date_close_approach': 1641565140000,
#      'relative_velocity': {'kilometers_per_second': '8.8180100069',
#       'kilometers_per_hour': '31744.8360247963',
#       'miles_per_hour': '19725.0065844074'},
#      'miss_distance': {'astronomical': '0.1247267296',
#       'lunar': '48.5186978144',
#       'kilometers': '18658853.080225952',
#       'miles': '11594073.6797120576'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2022-01-03': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3313974?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3313974',
#    'neo_reference_id': '3313974',
#    'name': '(2006 BV39)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3313974',
#    'absolute_magnitude_h': 29.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0040230458,
#      'estimated_diameter_max': 0.0089958039},
#     'meters': {'estimated_diameter_min': 4.0230457983,
#      'estimated_diameter_max': 8.9958038817},
#     'miles': {'estimated_diameter_min': 0.002499804,
#      'estimated_diameter_max': 0.0055897317},
#     'feet': {'estimated_diameter_min': 13.198969577,
#      'estimated_diameter_max': 29.5137932072}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 18:46',
#      'epoch_date_close_approach': 1641235560000,
#      'relative_velocity': {'kilometers_per_second': '22.7391653876',
#       'kilometers_per_hour': '81860.9953952192',
#       'miles_per_hour': '50865.239055435'},
#      'miss_distance': {'astronomical': '0.4926957707',
#       'lunar': '191.6586548023',
#       'kilometers': '73706237.854728409',
#       'miles': '45798932.4782096842'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3366282?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3366282',
#    'neo_reference_id': '3366282',
#    'name': '(2007 BD)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3366282',
#    'absolute_magnitude_h': 25.4,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#      'estimated_diameter_max': 0.0494356193},
#     'meters': {'estimated_diameter_min': 22.1082810359,
#      'estimated_diameter_max': 49.435619262},
#     'miles': {'estimated_diameter_min': 0.0137374447,
#      'estimated_diameter_max': 0.0307178602},
#     'feet': {'estimated_diameter_min': 72.5337327539,
#      'estimated_diameter_max': 162.1903570994}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 21:43',
#      'epoch_date_close_approach': 1641246180000,
#      'relative_velocity': {'kilometers_per_second': '19.3262110391',
#       'kilometers_per_hour': '69574.3597407704',
#       'miles_per_hour': '43230.8014733693'},
#      'miss_distance': {'astronomical': '0.3772486341',
#       'lunar': '146.7497186649',
#       'kilometers': '56435592.121769367',
#       'miles': '35067450.8451645846'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2022-01-04': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3555070?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3555070',
#    'neo_reference_id': '3555070',
#    'name': '(2011 AU4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3555070',
#    'absolute_magnitude_h': 25.9,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0175612318,
#      'estimated_diameter_max': 0.0392681082},
#     'meters': {'estimated_diameter_min': 17.561231848,
#      'estimated_diameter_max': 39.2681081809},
#     'miles': {'estimated_diameter_min': 0.0109120402,
#      'estimated_diameter_max': 0.0244000636},
#     'feet': {'estimated_diameter_min': 57.6155918963,
#      'estimated_diameter_max': 128.8323800441}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-04',
#      'close_approach_date_full': '2022-Jan-04 07:35',
#      'epoch_date_close_approach': 1641281700000,
#      'relative_velocity': {'kilometers_per_second': '13.3437442927',
#       'kilometers_per_hour': '48037.479453581',
#       'miles_per_hour': '29848.6216082543'},
#      'miss_distance': {'astronomical': '0.3426083627',
#       'lunar': '133.2746530903',
#       'kilometers': '51253481.304107449',
#       'miles': '31847436.4971188362'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3595775?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3595775',
#    'neo_reference_id': '3595775',
#    'name': '(2012 AB11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3595775',
#    'absolute_magnitude_h': 22.32,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#      'estimated_diameter_max': 0.2041925905},
#     'meters': {'estimated_diameter_min': 91.3177025518,
#      'estimated_diameter_max': 204.1925904549},
#     'miles': {'estimated_diameter_min': 0.0567421722,
#      'estimated_diameter_max': 0.1268793541},
#     'feet': {'estimated_diameter_min': 299.59877124,
#      'estimated_diameter_max': 669.9232184681}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-04',
#      'close_approach_date_full': '2022-Jan-04 14:14',
#      'epoch_date_close_approach': 1641305640000,
#      'relative_velocity': {'kilometers_per_second': '17.6164585855',
#       'kilometers_per_hour': '63419.2509076765',
#       'miles_per_hour': '39406.2562098282'},
#      'miss_distance': {'astronomical': '0.2383755028',
#       'lunar': '92.7280705892',
#       'kilometers': '35660467.479059036',
#       'miles': '22158386.9934292568'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3671126?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3671126',
#    'neo_reference_id': '3671126',
#    'name': '(2014 JJ55)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3671126',
#    'absolute_magnitude_h': 25.3,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0231502122,
#      'estimated_diameter_max': 0.0517654482},
#     'meters': {'estimated_diameter_min': 23.150212221,
#      'estimated_diameter_max': 51.7654482198},
#     'miles': {'estimated_diameter_min': 0.0143848705,
#      'estimated_diameter_max': 0.0321655483},
#     'feet': {'estimated_diameter_min': 75.9521422633,
#      'estimated_diameter_max': 169.8341531374}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-04',
#      'close_approach_date_full': '2022-Jan-04 19:50',
#      'epoch_date_close_approach': 1641325800000,
#      'relative_velocity': {'kilometers_per_second': '6.886716818',
#       'kilometers_per_hour': '24792.1805447869',
#       'miles_per_hour': '15404.896850176'},
#      'miss_distance': {'astronomical': '0.1852678346',
#       'lunar': '72.0691876594',
#       'kilometers': '27715673.435672302',
#       'miles': '17221720.8911176876'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3780740?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3780740',
#    'neo_reference_id': '3780740',
#    'name': '(2017 QW1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3780740',
#    'absolute_magnitude_h': 26.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152951935,
#      'estimated_diameter_max': 0.0342010925},
#     'meters': {'estimated_diameter_min': 15.2951935344,
#      'estimated_diameter_max': 34.201092472},
#     'miles': {'estimated_diameter_min': 0.0095039897,
#      'estimated_diameter_max': 0.021251567},
#     'feet': {'estimated_diameter_min': 50.1810827555,
#      'estimated_diameter_max': 112.2083122258}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-04',
#      'close_approach_date_full': '2022-Jan-04 00:29',
#      'epoch_date_close_approach': 1641256140000,
#      'relative_velocity': {'kilometers_per_second': '8.0150396385',
#       'kilometers_per_hour': '28854.1426986551',
#       'miles_per_hour': '17928.8421673949'},
#      'miss_distance': {'astronomical': '0.1371233644',
#       'lunar': '53.3409887516',
#       'kilometers': '20513363.241473828',
#       'miles': '12746412.8592337064'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2668499?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '2668499',
#    'neo_reference_id': '2668499',
#    'name': '668499 (2012 AB11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2668499',
#    'absolute_magnitude_h': 22.32,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#      'estimated_diameter_max': 0.2041925905},
#     'meters': {'estimated_diameter_min': 91.3177025518,
#      'estimated_diameter_max': 204.1925904549},
#     'miles': {'estimated_diameter_min': 0.0567421722,
#      'estimated_diameter_max': 0.1268793541},
#     'feet': {'estimated_diameter_min': 299.59877124,
#      'estimated_diameter_max': 669.9232184681}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-04',
#      'close_approach_date_full': '2022-Jan-04 14:14',
#      'epoch_date_close_approach': 1641305640000,
#      'relative_velocity': {'kilometers_per_second': '17.6164585635',
#       'kilometers_per_hour': '63419.2508286486',
#       'miles_per_hour': '39406.2561607233'},
#      'miss_distance': {'astronomical': '0.2383755028',
#       'lunar': '92.7280705892',
#       'kilometers': '35660467.479059036',
#       'miles': '22158386.9934292568'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2022-01-05': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3365921?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3365921',
#    'neo_reference_id': '3365921',
#    'name': '(2007 AM)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3365921',
#    'absolute_magnitude_h': 21.82,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1149621763,
#      'estimated_diameter_max': 0.257063241},
#     'meters': {'estimated_diameter_min': 114.9621762891,
#      'estimated_diameter_max': 257.0632410238},
#     'miles': {'estimated_diameter_min': 0.0714341624,
#      'estimated_diameter_max': 0.1597316431},
#     'feet': {'estimated_diameter_min': 377.1725064563,
#      'estimated_diameter_max': 843.3833636804}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-05',
#      'close_approach_date_full': '2022-Jan-05 02:20',
#      'epoch_date_close_approach': 1641349200000,
#      'relative_velocity': {'kilometers_per_second': '11.365527618',
#       'kilometers_per_hour': '40915.8994247244',
#       'miles_per_hour': '25423.5487286572'},
#      'miss_distance': {'astronomical': '0.187637158',
#       'lunar': '72.990854462',
#       'kilometers': '28070119.16965346',
#       'miles': '17441963.257439348'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3479014?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3479014',
#    'neo_reference_id': '3479014',
#    'name': '(2009 WM105)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3479014',
#    'absolute_magnitude_h': 23.0,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0667659413,
#      'estimated_diameter_max': 0.1492931834},
#     'meters': {'estimated_diameter_min': 66.7659413495,
#      'estimated_diameter_max': 149.2931834393},
#     'miles': {'estimated_diameter_min': 0.0414864197,
#      'estimated_diameter_max': 0.0927664547},
#     'feet': {'estimated_diameter_min': 219.0483710172,
#      'estimated_diameter_max': 489.807047955}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-05',
#      'close_approach_date_full': '2022-Jan-05 15:36',
#      'epoch_date_close_approach': 1641396960000,
#      'relative_velocity': {'kilometers_per_second': '9.734200755',
#       'kilometers_per_hour': '35043.1227181288',
#       'miles_per_hour': '21774.4336689395'},
#      'miss_distance': {'astronomical': '0.2314700751',
#       'lunar': '90.0418592139',
#       'kilometers': '34627430.203700037',
#       'miles': '21516487.3958010306'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3702966?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3702966',
#    'neo_reference_id': '3702966',
#    'name': '(2014 YT9)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3702966',
#    'absolute_magnitude_h': 20.59,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2025606009,
#      'estimated_diameter_max': 0.4529392731},
#     'meters': {'estimated_diameter_min': 202.5606008648,
#      'estimated_diameter_max': 452.9392730968},
#     'miles': {'estimated_diameter_min': 0.1258652831,
#      'estimated_diameter_max': 0.2814433291},
#     'feet': {'estimated_diameter_min': 664.5689217411,
#      'estimated_diameter_max': 1486.0212847469}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-05',
#      'close_approach_date_full': '2022-Jan-05 12:45',
#      'epoch_date_close_approach': 1641386700000,
#      'relative_velocity': {'kilometers_per_second': '32.2897570914',
#       'kilometers_per_hour': '116243.1255289547',
#       'miles_per_hour': '72228.9576376996'},
#      'miss_distance': {'astronomical': '0.4768342941',
#       'lunar': '185.4885404049',
#       'kilometers': '71333394.740313567',
#       'miles': '44324516.1365065446'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2022-01-06': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3170204?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3170204',
#    'neo_reference_id': '3170204',
#    'name': '(2003 YS17)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3170204',
#    'absolute_magnitude_h': 21.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1272198785,
#      'estimated_diameter_max': 0.2844722965},
#     'meters': {'estimated_diameter_min': 127.2198785394,
#      'estimated_diameter_max': 284.4722965033},
#     'miles': {'estimated_diameter_min': 0.0790507431,
#      'estimated_diameter_max': 0.1767628354},
#     'feet': {'estimated_diameter_min': 417.3880663071,
#      'estimated_diameter_max': 933.3080892598}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 05:22',
#      'epoch_date_close_approach': 1641446520000,
#      'relative_velocity': {'kilometers_per_second': '18.7190203137',
#       'kilometers_per_hour': '67388.4731294219',
#       'miles_per_hour': '41872.5765397788'},
#      'miss_distance': {'astronomical': '0.2917149523',
#       'lunar': '113.4771164447',
#       'kilometers': '43639935.511231601',
#       'miles': '27116598.5132980538'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3310464?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3310464',
#    'neo_reference_id': '3310464',
#    'name': '(2006 AN)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3310464',
#    'absolute_magnitude_h': 24.36,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0356906927,
#      'estimated_diameter_max': 0.079806815},
#     'meters': {'estimated_diameter_min': 35.690692667,
#      'estimated_diameter_max': 79.8068149676},
#     'miles': {'estimated_diameter_min': 0.0221771614,
#      'estimated_diameter_max': 0.0495896404},
#     'feet': {'estimated_diameter_min': 117.0954521297,
#      'estimated_diameter_max': 261.8333908182}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 00:04',
#      'epoch_date_close_approach': 1641427440000,
#      'relative_velocity': {'kilometers_per_second': '4.6468802954',
#       'kilometers_per_hour': '16728.7690634073',
#       'miles_per_hour': '10394.6065327599'},
#      'miss_distance': {'astronomical': '0.1541403886',
#       'lunar': '59.9606111654',
#       'kilometers': '23059073.815532282',
#       'miles': '14328244.0594662116'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3403506?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3403506',
#    'neo_reference_id': '3403506',
#    'name': '(2008 DJ)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3403506',
#    'absolute_magnitude_h': 20.62,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1997813652,
#      'estimated_diameter_max': 0.4467247133},
#     'meters': {'estimated_diameter_min': 199.78136523,
#      'estimated_diameter_max': 446.7247132921},
#     'miles': {'estimated_diameter_min': 0.1241383467,
#      'estimated_diameter_max': 0.2775817818},
#     'feet': {'estimated_diameter_min': 655.4506943013,
#      'estimated_diameter_max': 1465.6323083572}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 14:26',
#      'epoch_date_close_approach': 1641479160000,
#      'relative_velocity': {'kilometers_per_second': '11.5390104936',
#       'kilometers_per_hour': '41540.4377769334',
#       'miles_per_hour': '25811.6125731173'},
#      'miss_distance': {'astronomical': '0.1701854261',
#       'lunar': '66.2021307529',
#       'kilometers': '25459377.249602407',
#       'miles': '15819723.4525789366'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3441843?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3441843',
#    'neo_reference_id': '3441843',
#    'name': '(2008 YK2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3441843',
#    'absolute_magnitude_h': 19.5,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3346223745,
#      'estimated_diameter_max': 0.7482383761},
#     'meters': {'estimated_diameter_min': 334.6223744549,
#      'estimated_diameter_max': 748.2383760735},
#     'miles': {'estimated_diameter_min': 0.2079246394,
#      'estimated_diameter_max': 0.464933628},
#     'feet': {'estimated_diameter_min': 1097.8424710066,
#      'estimated_diameter_max': 2454.8503937571}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 12:24',
#      'epoch_date_close_approach': 1641471840000,
#      'relative_velocity': {'kilometers_per_second': '15.102933025',
#       'kilometers_per_hour': '54370.5588900936',
#       'miles_per_hour': '33783.7508836807'},
#      'miss_distance': {'astronomical': '0.2272639708',
#       'lunar': '88.4056846412',
#       'kilometers': '33998205.959422196',
#       'miles': '21125505.5804744648'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3555163?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3555163',
#    'neo_reference_id': '3555163',
#    'name': '(2011 AR26)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3555163',
#    'absolute_magnitude_h': 20.28,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.233644185,
#      'estimated_diameter_max': 0.5224442801},
#     'meters': {'estimated_diameter_min': 233.6441849736,
#      'estimated_diameter_max': 522.4442801486},
#     'miles': {'estimated_diameter_min': 0.1451797209,
#      'estimated_diameter_max': 0.3246317248},
#     'feet': {'estimated_diameter_min': 766.5491878289,
#      'estimated_diameter_max': 1714.0560920828}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 22:35',
#      'epoch_date_close_approach': 1641508500000,
#      'relative_velocity': {'kilometers_per_second': '13.592238999',
#       'kilometers_per_hour': '48932.060396494',
#       'miles_per_hour': '30404.4794169215'},
#      'miss_distance': {'astronomical': '0.4641931866',
#       'lunar': '180.5711495874',
#       'kilometers': '69442311.983872542',
#       'miles': '43149451.8001113996'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3621814?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3621814',
#    'neo_reference_id': '3621814',
#    'name': '(2012 YL7)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3621814',
#    'absolute_magnitude_h': 22.74,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0752583992,
#      'estimated_diameter_max': 0.1682828966},
#     'meters': {'estimated_diameter_min': 75.2583992483,
#      'estimated_diameter_max': 168.2828965971},
#     'miles': {'estimated_diameter_min': 0.0467633868,
#      'estimated_diameter_max': 0.1045661117},
#     'feet': {'estimated_diameter_min': 246.9107665899,
#      'estimated_diameter_max': 552.1092584717}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 21:39',
#      'epoch_date_close_approach': 1641505140000,
#      'relative_velocity': {'kilometers_per_second': '11.0655614218',
#       'kilometers_per_hour': '39836.0211184656',
#       'miles_per_hour': '24752.5543444155'},
#      'miss_distance': {'astronomical': '0.4024854856',
#       'lunar': '156.5668538984',
#       'kilometers': '60210971.351675672',
#       'miles': '37413362.7172493936'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3701710?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3701710',
#    'neo_reference_id': '3701710',
#    'name': '(2014 WF497)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3701710',
#    'absolute_magnitude_h': 20.34,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2272767323,
#      'estimated_diameter_max': 0.5082062231},
#     'meters': {'estimated_diameter_min': 227.2767322847,
#      'estimated_diameter_max': 508.2062230927},
#     'miles': {'estimated_diameter_min': 0.1412231704,
#      'estimated_diameter_max': 0.315784609},
#     'feet': {'estimated_diameter_min': 745.6585943491,
#      'estimated_diameter_max': 1667.3433049715}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 05:06',
#      'epoch_date_close_approach': 1641445560000,
#      'relative_velocity': {'kilometers_per_second': '14.5446943187',
#       'kilometers_per_hour': '52360.899547158',
#       'miles_per_hour': '32535.0267213994'},
#      'miss_distance': {'astronomical': '0.3452040166',
#       'lunar': '134.2843624574',
#       'kilometers': '51641785.598804642',
#       'miles': '32088717.5974903796'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3703059?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3703059',
#    'neo_reference_id': '3703059',
#    'name': '(2014 YE15)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3703059',
#    'absolute_magnitude_h': 28.3,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0058150704,
#      'estimated_diameter_max': 0.0130028927},
#     'meters': {'estimated_diameter_min': 5.8150703965,
#      'estimated_diameter_max': 13.0028927004},
#     'miles': {'estimated_diameter_min': 0.0036133161,
#      'estimated_diameter_max': 0.0080796204},
#     'feet': {'estimated_diameter_min': 19.0783155595,
#      'estimated_diameter_max': 42.6604104873}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 03:54',
#      'epoch_date_close_approach': 1641441240000,
#      'relative_velocity': {'kilometers_per_second': '6.3796776658',
#       'kilometers_per_hour': '22966.8395969283',
#       'miles_per_hour': '14270.700970658'},
#      'miss_distance': {'astronomical': '0.0494909337',
#       'lunar': '19.2519732093',
#       'kilometers': '7403738.265831219',
#       'miles': '4600469.6317760622'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3786458?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3786458',
#    'neo_reference_id': '3786458',
#    'name': '(2017 UG)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3786458',
#    'absolute_magnitude_h': 27.5,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.008405334,
#      'estimated_diameter_max': 0.0187948982},
#     'meters': {'estimated_diameter_min': 8.4053340207,
#      'estimated_diameter_max': 18.7948982439},
#     'miles': {'estimated_diameter_min': 0.0052228308,
#      'estimated_diameter_max': 0.0116786047},
#     'feet': {'estimated_diameter_min': 27.5765560686,
#      'estimated_diameter_max': 61.6630539546}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-06',
#      'close_approach_date_full': '2022-Jan-06 14:15',
#      'epoch_date_close_approach': 1641478500000,
#      'relative_velocity': {'kilometers_per_second': '10.2843834093',
#       'kilometers_per_hour': '37023.780273547',
#       'miles_per_hour': '23005.1372483048'},
#      'miss_distance': {'astronomical': '0.318157399',
#       'lunar': '123.763228211',
#       'kilometers': '47595669.21514013',
#       'miles': '29574577.458908594'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2022-01-01': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2363505?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '2363505',
#    'neo_reference_id': '2363505',
#    'name': '363505 (2003 UC20)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2363505',
#    'absolute_magnitude_h': 18.47,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.5377184977,
#      'estimated_diameter_max': 1.2023751136},
#     'meters': {'estimated_diameter_min': 537.7184976927,
#      'estimated_diameter_max': 1202.3751135999},
#     'miles': {'estimated_diameter_min': 0.3341226806,
#      'estimated_diameter_max': 0.7471210267},
#     'feet': {'estimated_diameter_min': 1764.1683559701,
#      'estimated_diameter_max': 3944.8003677031}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 01:25',
#      'epoch_date_close_approach': 1641000300000,
#      'relative_velocity': {'kilometers_per_second': '12.5185405816',
#       'kilometers_per_hour': '45066.7460938774',
#       'miles_per_hour': '28002.723427054'},
#      'miss_distance': {'astronomical': '0.1576979316',
#       'lunar': '61.3444953924',
#       'kilometers': '23591274.670765692',
#       'miles': '14658938.3364108696'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2488490?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '2488490',
#    'neo_reference_id': '2488490',
#    'name': '488490 (2000 AF205)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2488490',
#    'absolute_magnitude_h': 21.9,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1108038821,
#      'estimated_diameter_max': 0.2477650126},
#     'meters': {'estimated_diameter_min': 110.8038821264,
#      'estimated_diameter_max': 247.7650126055},
#     'miles': {'estimated_diameter_min': 0.068850319,
#      'estimated_diameter_max': 0.1539539936},
#     'feet': {'estimated_diameter_min': 363.5298086356,
#      'estimated_diameter_max': 812.8773639568}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 15:49',
#      'epoch_date_close_approach': 1641052140000,
#      'relative_velocity': {'kilometers_per_second': '21.0773993912',
#       'kilometers_per_hour': '75878.6378083358',
#       'miles_per_hour': '47148.0346981851'},
#      'miss_distance': {'astronomical': '0.4071860722',
#       'lunar': '158.3953820858',
#       'kilometers': '60914169.094786214',
#       'miles': '37850309.5333251932'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3388081?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3388081',
#    'neo_reference_id': '3388081',
#    'name': '(2007 TL23)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3388081',
#    'absolute_magnitude_h': 21.48,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1344481952,
#      'estimated_diameter_max': 0.3006353038},
#     'meters': {'estimated_diameter_min': 134.4481951604,
#      'estimated_diameter_max': 300.6353038309},
#     'miles': {'estimated_diameter_min': 0.0835422095,
#      'estimated_diameter_max': 0.1868060594},
#     'feet': {'estimated_diameter_min': 441.1030166101,
#      'estimated_diameter_max': 986.3363302205}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 17:46',
#      'epoch_date_close_approach': 1641059160000,
#      'relative_velocity': {'kilometers_per_second': '31.1009901975',
#       'kilometers_per_hour': '111963.5647109464',
#       'miles_per_hour': '69569.8049727544'},
#      'miss_distance': {'astronomical': '0.1976817951',
#       'lunar': '76.8982182939',
#       'kilometers': '29572775.484736437',
#       'miles': '18375670.5950473506'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3592308?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3592308',
#    'neo_reference_id': '3592308',
#    'name': '(2012 AP10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3592308',
#    'absolute_magnitude_h': 26.5,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0133215567,
#      'estimated_diameter_max': 0.0297879063},
#     'meters': {'estimated_diameter_min': 13.3215566698,
#      'estimated_diameter_max': 29.7879062798},
#     'miles': {'estimated_diameter_min': 0.008277629,
#      'estimated_diameter_max': 0.0185093411},
#     'feet': {'estimated_diameter_min': 43.7058959846,
#      'estimated_diameter_max': 97.7293544391}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 18:51',
#      'epoch_date_close_approach': 1641063060000,
#      'relative_velocity': {'kilometers_per_second': '15.9959341425',
#       'kilometers_per_hour': '57585.3629130324',
#       'miles_per_hour': '35781.3050833784'},
#      'miss_distance': {'astronomical': '0.3971181533',
#       'lunar': '154.4789616337',
#       'kilometers': '59408029.872013471',
#       'miles': '36914438.0172330598'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3744561?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3744561',
#    'neo_reference_id': '3744561',
#    'name': '(2016 CN248)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3744561',
#    'absolute_magnitude_h': 27.3,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0092162655,
#      'estimated_diameter_max': 0.0206081961},
#     'meters': {'estimated_diameter_min': 9.216265485,
#      'estimated_diameter_max': 20.6081961232},
#     'miles': {'estimated_diameter_min': 0.0057267201,
#      'estimated_diameter_max': 0.0128053354},
#     'feet': {'estimated_diameter_min': 30.2370924539,
#      'estimated_diameter_max': 67.6121941689}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 20:11',
#      'epoch_date_close_approach': 1641067860000,
#      'relative_velocity': {'kilometers_per_second': '10.6983078965',
#       'kilometers_per_hour': '38513.9084274605',
#       'miles_per_hour': '23931.0449337184'},
#      'miss_distance': {'astronomical': '0.4066875807',
#       'lunar': '158.2014688923',
#       'kilometers': '60839595.828173109',
#       'miles': '37803971.8541585442'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3771592?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3771592',
#    'neo_reference_id': '3771592',
#    'name': '(2017 DA120)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3771592',
#    'absolute_magnitude_h': 19.61,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3180936332,
#      'estimated_diameter_max': 0.7112789871},
#     'meters': {'estimated_diameter_min': 318.0936332215,
#      'estimated_diameter_max': 711.2789870931},
#     'miles': {'estimated_diameter_min': 0.197654159,
#      'estimated_diameter_max': 0.4419681355},
#     'feet': {'estimated_diameter_min': 1043.6143156183,
#      'estimated_diameter_max': 2333.5925520145}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 01:31',
#      'epoch_date_close_approach': 1641000660000,
#      'relative_velocity': {'kilometers_per_second': '18.5787910301',
#       'kilometers_per_hour': '66883.6477083809',
#       'miles_per_hour': '41558.8976552437'},
#      'miss_distance': {'astronomical': '0.4700557324',
#       'lunar': '182.8516799036',
#       'kilometers': '70319336.348329988',
#       'miles': '43694409.4701623144'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3775153?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3775153',
#    'neo_reference_id': '3775153',
#    'name': '(2017 KU34)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3775153',
#    'absolute_magnitude_h': 23.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0506471459,
#      'estimated_diameter_max': 0.1132504611},
#     'meters': {'estimated_diameter_min': 50.6471458835,
#      'estimated_diameter_max': 113.2504610618},
#     'miles': {'estimated_diameter_min': 0.0314706677,
#      'estimated_diameter_max': 0.0703705522},
#     'feet': {'estimated_diameter_min': 166.1651821003,
#      'estimated_diameter_max': 371.5566426699}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 18:25',
#      'epoch_date_close_approach': 1641061500000,
#      'relative_velocity': {'kilometers_per_second': '10.1460896076',
#       'kilometers_per_hour': '36525.9225873848',
#       'miles_per_hour': '22695.7878432559'},
#      'miss_distance': {'astronomical': '0.1833710837',
#       'lunar': '71.3313515593',
#       'kilometers': '27431923.541111719',
#       'miles': '17045406.8824269622'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3795123?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3795123',
#    'neo_reference_id': '3795123',
#    'name': '(2017 YK7)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3795123',
#    'absolute_magnitude_h': 24.56,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0325502986,
#      'estimated_diameter_max': 0.0727846803},
#     'meters': {'estimated_diameter_min': 32.5502985765,
#      'estimated_diameter_max': 72.7846803049},
#     'miles': {'estimated_diameter_min': 0.0202258116,
#      'estimated_diameter_max': 0.0452262896},
#     'feet': {'estimated_diameter_min': 106.7923215816,
#      'estimated_diameter_max': 238.7948905315}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 18:10',
#      'epoch_date_close_approach': 1641060600000,
#      'relative_velocity': {'kilometers_per_second': '21.9952907107',
#       'kilometers_per_hour': '79183.0465586744',
#       'miles_per_hour': '49201.2657908608'},
#      'miss_distance': {'astronomical': '0.3664586392',
#       'lunar': '142.5524106488',
#       'kilometers': '54821431.867418504',
#       'miles': '34064458.1724991952'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3825582?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3825582',
#    'neo_reference_id': '3825582',
#    'name': '(2018 NQ1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3825582',
#    'absolute_magnitude_h': 25.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0253837029,
#      'estimated_diameter_max': 0.0567596853},
#     'meters': {'estimated_diameter_min': 25.3837029364,
#      'estimated_diameter_max': 56.7596852866},
#     'miles': {'estimated_diameter_min': 0.0157726969,
#      'estimated_diameter_max': 0.0352688224},
#     'feet': {'estimated_diameter_min': 83.279867942,
#      'estimated_diameter_max': 186.2194458756}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 23:29',
#      'epoch_date_close_approach': 1641079740000,
#      'relative_velocity': {'kilometers_per_second': '7.8010080242',
#       'kilometers_per_hour': '28083.6288870371',
#       'miles_per_hour': '17450.0748492814'},
#      'miss_distance': {'astronomical': '0.4642049559',
#       'lunar': '180.5757278451',
#       'kilometers': '69444072.646083933',
#       'miles': '43150545.8248789554'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54248460?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '54248460',
#    'neo_reference_id': '54248460',
#    'name': '(2022 DE2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54248460',
#    'absolute_magnitude_h': 19.57,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3240074354,
#      'estimated_diameter_max': 0.7245026508},
#     'meters': {'estimated_diameter_min': 324.0074353942,
#      'estimated_diameter_max': 724.5026507569},
#     'miles': {'estimated_diameter_min': 0.2013288241,
#      'estimated_diameter_max': 0.4501849366},
#     'feet': {'estimated_diameter_min': 1063.0165543388,
#      'estimated_diameter_max': 2376.9772767092}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-01',
#      'close_approach_date_full': '2022-Jan-01 01:39',
#      'epoch_date_close_approach': 1641001140000,
#      'relative_velocity': {'kilometers_per_second': '18.5807868886',
#       'kilometers_per_hour': '66890.8327988686',
#       'miles_per_hour': '41563.3621910525'},
#      'miss_distance': {'astronomical': '0.4700503163',
#       'lunar': '182.8495730407',
#       'kilometers': '70318526.111306281',
#       'miles': '43693906.0122214378'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2022-01-02': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3625335?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3625335',
#    'neo_reference_id': '3625335',
#    'name': '(2013 BC70)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3625335',
#    'absolute_magnitude_h': 24.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.040230458,
#      'estimated_diameter_max': 0.0899580388},
#     'meters': {'estimated_diameter_min': 40.2304579834,
#      'estimated_diameter_max': 89.9580388169},
#     'miles': {'estimated_diameter_min': 0.0249980399,
#      'estimated_diameter_max': 0.0558973165},
#     'feet': {'estimated_diameter_min': 131.9896957704,
#      'estimated_diameter_max': 295.1379320721}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 04:13',
#      'epoch_date_close_approach': 1641096780000,
#      'relative_velocity': {'kilometers_per_second': '10.1548261794',
#       'kilometers_per_hour': '36557.3742457644',
#       'miles_per_hour': '22715.3306806529'},
#      'miss_distance': {'astronomical': '0.1416245844',
#       'lunar': '55.0919633316',
#       'kilometers': '21186736.165875228',
#       'miles': '13164827.3923170264'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3753290?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3753290',
#    'neo_reference_id': '3753290',
#    'name': '(2016 JT28)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3753290',
#    'absolute_magnitude_h': 23.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0483676488,
#      'estimated_diameter_max': 0.1081533507},
#     'meters': {'estimated_diameter_min': 48.3676488219,
#      'estimated_diameter_max': 108.1533506775},
#     'miles': {'estimated_diameter_min': 0.0300542543,
#      'estimated_diameter_max': 0.0672033557},
#     'feet': {'estimated_diameter_min': 158.6865169607,
#      'estimated_diameter_max': 354.8338390368}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 02:29',
#      'epoch_date_close_approach': 1641090540000,
#      'relative_velocity': {'kilometers_per_second': '13.5100245697',
#       'kilometers_per_hour': '48636.0884509632',
#       'miles_per_hour': '30220.5739599888'},
#      'miss_distance': {'astronomical': '0.1726248284',
#       'lunar': '67.1510582476',
#       'kilometers': '25824306.637755508',
#       'miles': '16046480.0595336904'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3756934?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3756934',
#    'neo_reference_id': '3756934',
#    'name': '(2016 PC2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3756934',
#    'absolute_magnitude_h': 23.0,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0667659413,
#      'estimated_diameter_max': 0.1492931834},
#     'meters': {'estimated_diameter_min': 66.7659413495,
#      'estimated_diameter_max': 149.2931834393},
#     'miles': {'estimated_diameter_min': 0.0414864197,
#      'estimated_diameter_max': 0.0927664547},
#     'feet': {'estimated_diameter_min': 219.0483710172,
#      'estimated_diameter_max': 489.807047955}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 05:02',
#      'epoch_date_close_approach': 1641099720000,
#      'relative_velocity': {'kilometers_per_second': '20.4077209528',
#       'kilometers_per_hour': '73467.7954302229',
#       'miles_per_hour': '45650.0309994071'},
#      'miss_distance': {'astronomical': '0.495238863',
#       'lunar': '192.647917707',
#       'kilometers': '74086679.04602181',
#       'miles': '46035327.672688578'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3826839?api_key=BDusIUFAIxiYUxg5sruVGNMf0AAskKMPqrYQ1TbT'},
#    'id': '3826839',
#    'neo_reference_id': '3826839',
#    'name': '(2018 PR23)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3826839',
#    'absolute_magnitude_h': 25.4,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#      'estimated_diameter_max': 0.0494356193},
#     'meters': {'estimated_diameter_min': 22.1082810359,
#      'estimated_diameter_max': 49.435619262},
#     'miles': {'estimated_diameter_min': 0.0137374447,
#      'estimated_diameter_max': 0.0307178602},
#     'feet': {'estimated_diameter_min': 72.5337327539,
#      'estimated_diameter_max': 162.1903570994}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 02:04',
#      'epoch_date_close_approach': 1641089040000,
#      'relative_velocity': {'kilometers_per_second': '8.4332699552',
#       'kilometers_per_hour': '30359.7718385923',
#       'miles_per_hour': '18864.3815627076'},
#      'miss_distance': {'astronomical': '0.4832391866',
#       'lunar': '187.9800435874',
#       'kilometers': '72291553.015892542',
#       'miles': '44919888.0811873996'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}]}

# %%
res['near_earth_objects'].keys()
# Out:
# dict_keys(['2022-01-07', '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-01', '2022-01-02'])

# %% [markdown]
# **Question:** How many near earth objects were there on January 3?

# %%
# Your Code Here
len(res['near_earth_objects']['2022-01-03'])
# Out:
# 2

# %% [markdown]
# **Question:** Is the first returned result for January 3 potentially hazardous (as indicated by the `is_potentially_hazardous_asteroid` field)?

# %%
# Your Code Here
res['near_earth_objects']['2022-01-03'][0]['is_potentially_hazardous_asteroid']
# Out:
# False

# %% [markdown]
# **Question:** What was the relative velocity, in miles per hour of the first object returned for January 3?

# %%
# Your Code Here
res['near_earth_objects']['2022-01-03'][0]['close_approach_data'][0]['relative_velocity']['miles_per_hour']
# Out:
# '50865.239055435'

# %% [markdown]
# The for loop below iterates over the data returned and pulls out information for each asteroid. It then saves the information to lists, that are used for making a scatter plot of the asteroids.

# %%
max_diam = []
hazardous = []
miss_dist = []
for day, objs in res['near_earth_objects'].items():
    for obj in objs:
        max_diam.append(float(obj['estimated_diameter']['miles']['estimated_diameter_max']))
        hazardous.append(obj['is_potentially_hazardous_asteroid'])
        miss_dist.append(float(obj['close_approach_data'][0]['miss_distance']['miles']))

plt.figure(figsize = (17, 10))
plt.scatter(max_diam, miss_dist, c = hazardous)
plt.xlabel('max diameter (miles)')
plt.ylabel('miss distance (miles)');

# %% [markdown]
# If you want to work with the response from an API using _pandas_, you'll want to convert it to a DataFrame. In some circumstances, you can easily convert a json to a DataFrame, but in other cases, you have to do a little bit of work.

# %%
import pandas as pd

# %% [markdown]
# The easiest case is when you have a list of dictionaries. Here, you can simply use the `DataFrame` constructor. Let's see how this works using one of the days. If you wanted to get all of the results into a single DataFrame, you could iterate through and concatenate.

# %%
pd.DataFrame(response.json()['near_earth_objects']['2022-01-07']).head(2)
# Out:
#                                                links       id  \
# 0  {'self': 'http://api.nasa.gov/neo/rest/v1/neo/...  2494697
# 1  {'self': 'http://api.nasa.gov/neo/rest/v1/neo/...  2496860
#
#   neo_reference_id                 name  \
# 0          2494697   494697 (2004 SW55)
# 1          2496860  496860 (1999 XL136)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.77
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.67
#
#                                   estimated_diameter  \
# 0  {'kilometers': {'estimated_diameter_min': 0.18...
# 1  {'kilometers': {'estimated_diameter_min': 0.30...
#
#    is_potentially_hazardous_asteroid  \
# 0                               True
# 1                               True
#
#                                  close_approach_data  is_sentry_object
# 0  [{'close_approach_date': '2022-01-07', 'close_...             False
# 1  [{'close_approach_date': '2022-01-07', 'close_...             False

# %% [markdown]
# You'll notice that we still have dictionaries in some of the columns. This can be remedied using the `json_normalize` function.

# %%
pd.json_normalize(response.json()['near_earth_objects']['2022-01-07']).head(2)
# Out:
#         id neo_reference_id                 name  \
# 0  2494697          2494697   494697 (2004 SW55)
# 1  2496860          2496860  496860 (1999 XL136)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.77
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.67
#
#    is_potentially_hazardous_asteroid  \
# 0                               True
# 1                               True
#
#                                  close_approach_data  is_sentry_object  \
# 0  [{'close_approach_date': '2022-01-07', 'close_...             False
# 1  [{'close_approach_date': '2022-01-07', 'close_...             False
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/2494697?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/2496860?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.186447
# 1                                           0.309425
#
#    estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                           0.416908
# 1                                           0.691895
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        186.446818
# 1                                        309.424699
#
#    estimated_diameter.meters.estimated_diameter_max  \
# 0                                         416.90776
# 1                                         691.89466
#
#    estimated_diameter.miles.estimated_diameter_min  \
# 0                                         0.115853
# 1                                         0.192268
#
#    estimated_diameter.miles.estimated_diameter_max  \
# 0                                         0.259054
# 1                                         0.429923
#
#    estimated_diameter.feet.estimated_diameter_min  \
# 0                                      611.702179
# 1                                     1015.172928
#
#    estimated_diameter.feet.estimated_diameter_max
# 0                                     1367.807655
# 1                                     2269.995676

# %% [markdown]
# This almost does it, but the `close_approach_data` column contains a list, which `json_normalize` can't handle. To fix this, we can use the `explode` method which will unpack the list across multiple columns, if needed.

# %%
response_df = pd.json_normalize(response.json()['near_earth_objects']['2022-01-07'])
response_df.explode('close_approach_data').head(2)
# Out:
#         id neo_reference_id                 name  \
# 0  2494697          2494697   494697 (2004 SW55)
# 1  2496860          2496860  496860 (1999 XL136)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.77
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.67
#
#    is_potentially_hazardous_asteroid  \
# 0                               True
# 1                               True
#
#                                  close_approach_data  is_sentry_object  \
# 0  {'close_approach_date': '2022-01-07', 'close_a...             False
# 1  {'close_approach_date': '2022-01-07', 'close_a...             False
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/2494697?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/2496860?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.186447
# 1                                           0.309425
#
#    estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                           0.416908
# 1                                           0.691895
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        186.446818
# 1                                        309.424699
#
#    estimated_diameter.meters.estimated_diameter_max  \
# 0                                         416.90776
# 1                                         691.89466
#
#    estimated_diameter.miles.estimated_diameter_min  \
# 0                                         0.115853
# 1                                         0.192268
#
#    estimated_diameter.miles.estimated_diameter_max  \
# 0                                         0.259054
# 1                                         0.429923
#
#    estimated_diameter.feet.estimated_diameter_min  \
# 0                                      611.702179
# 1                                     1015.172928
#
#    estimated_diameter.feet.estimated_diameter_max
# 0                                     1367.807655
# 1                                     2269.995676

# %% [markdown]
# Once exploded, you can use the `json_normalize` function again.

# %%
pd.json_normalize(response_df.explode('close_approach_data')['close_approach_data']).head(2)
# Out:
#   close_approach_date close_approach_date_full  epoch_date_close_approach  \
# 0          2022-01-07        2022-Jan-07 12:09              1641557340000
# 1          2022-01-07        2022-Jan-07 02:07              1641521220000
#
#   orbiting_body relative_velocity.kilometers_per_second  \
# 0         Earth                           10.0478001196
# 1         Earth                           16.7624360583
#
#   relative_velocity.kilometers_per_hour relative_velocity.miles_per_hour  \
# 0                      36172.0804304837                 22475.9240874858
# 1                      60344.7698097014                 37495.8932187003
#
#   miss_distance.astronomical miss_distance.lunar miss_distance.kilometers  \
# 0               0.1338706738       52.0756921082       20026767.655944806
# 1               0.0895472705       34.8338882245       13396080.931113835
#
#    miss_distance.miles
# 0  12444056.3828420828
# 1    8323938.704427523

# %% [markdown]
# And finally, you can concatenate the two pieces together.

# %%
pd.concat([
    response_df.explode('close_approach_data').drop(columns = ['close_approach_data']),
    pd.json_normalize(response_df.explode('close_approach_data')['close_approach_data'])
], axis = 1).head(2)
# Out:
#         id neo_reference_id                 name  \
# 0  2494697          2494697   494697 (2004 SW55)
# 1  2496860          2496860  496860 (1999 XL136)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.77
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.67
#
#    is_potentially_hazardous_asteroid  is_sentry_object  \
# 0                               True             False
# 1                               True             False
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/2494697?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/2496860?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.186447
# 1                                           0.309425
#
#    estimated_diameter.kilometers.estimated_diameter_max  ...  \
# 0                                           0.416908     ...
# 1                                           0.691895     ...
#
#    close_approach_date_full  epoch_date_close_approach  orbiting_body  \
# 0         2022-Jan-07 12:09              1641557340000          Earth
# 1         2022-Jan-07 02:07              1641521220000          Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                            10.0478001196
# 1                            16.7624360583
#
#    relative_velocity.kilometers_per_hour  relative_velocity.miles_per_hour  \
# 0                       36172.0804304837                  22475.9240874858
# 1                       60344.7698097014                  37495.8932187003
#
#   miss_distance.astronomical miss_distance.lunar  miss_distance.kilometers  \
# 0               0.1338706738       52.0756921082        20026767.655944806
# 1               0.0895472705       34.8338882245        13396080.931113835
#
#    miss_distance.miles
# 0  12444056.3828420828
# 1    8323938.704427523
#
# [2 rows x 27 columns]

# %% [markdown]
# Let's try another `endpoint` from NASA. This time copy the endpoint from the **APOD** (Astronomy Picture of the Day) section.
#
# Fill in the endpoint and parameters in order to retrieve the image for January 1, 2019.

# %%
endpoint = 'https://api.nasa.gov/planetary/apod'

params = { 'start_date' : "2022-01-01",
          'end_date' : "2022-01-07",
          'api_key' : api_key 
          

}

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'copyright': 'Soumyadeep Mukherjee',
#   'date': '2022-01-01',
#   'explanation': "very Full Moon of 2021 shines in this year-spanning astrophoto project, a composite portrait of the familiar lunar nearside at each brightest lunar phase. Arranged by moonth, the year progresses in stripes beginning at the top. Taken with the same camera and lens the stripes are from Full Moon images all combined at the same pixel scale. The stripes still look mismatched, but they show that the Full Moon's angular size changes throughout the year depending on its distance from Kolkata, India, planet Earth. The calendar month, a full moon name, distance in kilometers, and angular size is indicated for each stripe. Angular size is given in minutes of arc corresponding to 1/60th of a degree. The largest Full Moon is near a perigee or closest approach in May. The smallest is near an apogee, the most distant Full Moon in December. Of course the full moons of May and November also slid into Earth's shadow during 2021's two lunar eclipses.",
#   'hdurl': 'https://apod.nasa.gov/apod/image/2201/MoonstripsAnnotatedIG.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'The Full Moon of 2021',
#   'url': 'https://apod.nasa.gov/apod/image/2201/MoonstripsAnnotatedIG_crop1024.jpg'},
#  {'copyright': '\nDani Caxete\n',
#   'date': '2022-01-02',
#   'explanation': 'Sometimes falling ice crystals make the atmosphere into a giant lens causing arcs and halos to appear around the Sun or Moon. One Saturday night in 2012 was just such a time near Madrid, Spain, where a winter sky displayed not only a bright Moon but four rare lunar halos.  The brightest object, near the top of the featured image, is the Moon. Light from the Moon refracts through tumbling hexagonal ice crystals into a somewhat rare 22-degree halo seen surrounding the Moon. Elongating the 22-degree arc horizontally is a more rare circumscribed halo caused by column ice crystals. Even more rare, some moonlight refracts through more distant tumbling ice crystals to form a (third) rainbow-like arc 46 degrees from the Moon and appearing here just above a picturesque winter landscape. Furthermore, part of a whole 46-degree circular halo is also visible, so that an extremely rare -- especially for the Moon --  quadruple halo  was captured. Far in the background is a famous winter skyscape that includes Sirius, the belt of Orion, and Betelgeuse -- visible between the inner and outer arcs. Halos and arcs typically last for minutes to hours, so if you do see one there should be time to invite family, friends or neighbors to share your unusual lensed vista of the sky.',
#   'hdurl': 'https://apod.nasa.gov/apod/image/2201/lunararcs_caxete_1280.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'Quadruple Lunar Halo Over Winter Road',
#   'url': 'https://apod.nasa.gov/apod/image/2201/lunararcs_caxete_960.jpg'},
#  {'copyright': '\nJan Hattenbach\n',
#   'date': '2022-01-03',
#   'explanation': "You couldn't see Comet Leonard’s extremely long tail with a telescope — it was just too long. You also couldn't see it with binoculars — still too long. Or with your eyes -- it was too dim. Or from a city — the sky was too bright. But from a dark location with a low horizon — your camera could. And still might -- if the comet survives today's closest encounter with the Sun, which occurs between the orbits of Mercury and Venus. The featured picture was created from two deep and wide-angle camera images taken from La Palma in the Canary Islands of Spain late last month.  Afterwards, if it survives, what is left of Comet Leonard's nucleus will head out of our Solar System, never to return.",
#   'hdurl': 'https://apod.nasa.gov/apod/image/2201/LeonardTail_Hattenbach_1600.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': "Comet Leonard's Long Tail",
#   'url': 'https://apod.nasa.gov/apod/image/2201/LeonardTail_Hattenbach_960.jpg'},
#  {'date': '2022-01-04',
#   'explanation': "What's happened to that moon of Saturn? Nothing -- Saturn's moon Rhea is just partly hidden behind Saturn's rings. In 2010, the robotic Cassini spacecraft then orbiting Saturn took this narrow-angle view looking across the Solar System's most famous rings. Rings visible in the foreground include the thin F ring on the outside and the much wider A and B rings just interior to it. Although it seems to be hovering over the rings, Saturn's moon Janus is actually far behind them.  Janus is one of Saturn's smaller moons and measures only about 180 kilometers across. Farther out from the camera is the heavily cratered Rhea, a much larger moon measuring 1,500 kilometers across. The top of Rhea is visible only through gaps in the rings. After more than a decade of exploration and discovery, the Cassini spacecraft ran low on fuel in 2017 and was directed to enter Saturn's atmosphere, where it surely melted.   Explore Your Universe: Random APOD Generator",
#   'hdurl': 'https://apod.nasa.gov/apod/image/2201/RheaJanus_Cassini_1020.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'Moons Beyond Rings at Saturn',
#   'url': 'https://apod.nasa.gov/apod/image/2201/RheaJanus_Cassini_1020.jpg'},
#  {'copyright': '\nLuca Vanzella\n',
#   'date': '2022-01-05',
#   'explanation': "Does the Sun always rise in the same direction?  No.  As the months change, the direction toward the rising Sun changes, too.  The featured image shows the direction of sunrise every month during 2021 as seen from the city of Edmonton, Alberta, Canada. The camera in the image is always facing due east, with north toward the left and south toward the right.  As shown in an accompanying video, the top image was taken in 2020 December, while the bottom image was captured in 2021 December, making 13 images in total. Although the Sun always rises in the east in general, it rises furthest to the south of east near the December solstice, and furthest north of east near the June solstice. In many countries, the December Solstice is considered an official change in season: for example the first day of winter in the North.  Solar heating and stored energy in the Earth's surface and atmosphere are near their lowest during winter, making the winter season the coldest of the year.    Status Updates: Deploying the James Webb Space Telescope",
#   'hdurl': 'https://apod.nasa.gov/apod/image/2201/SunriseYear_Vanzella_2400.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'A Year of Sunrises',
#   'url': 'https://apod.nasa.gov/apod/image/2201/SunriseYear_Vanzella_960.jpg'},
#  {'copyright': 'Tamas Ladanyi',
#   'date': '2022-01-06',
#   'explanation': "That's not a young crescent Moon posing behind cathedral towers after sunset. It's Venus in a crescent phase. About 40 million kilometers away and about 2 percent illuminated by sunlight, it was captured with camera and telephoto lens in this series of exposures as it set in western skies on January 1 from Veszprem, Hungary. The bright celestial beacon was languishing in the evening twilight, its days as the Evening Star coming to a close as 2022 began. But it was also growing larger in apparent size and becoming an ever thinner crescent in telescopic views. Heading toward a (non-judgemental) inferior conjunction, the inner planet will be positioned between Earth and Sun on January 9 and generally lost from view in the solar glare. A crescent Venus will soon reappear though. Rising in the east by mid-month just before the Sun as the brilliant Morning Star.   Status Updates: Deploying the James Webb Space Telescope",
#   'hdurl': 'https://apod.nasa.gov/apod/image/2201/venus_220101_ladanyi_web.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'The Last Days of Venus as the Evening Star',
#   'url': 'https://apod.nasa.gov/apod/image/2201/venus_220101_ladanyi_web1024.jpg'},
#  {'copyright': 'Point Blue Conservation Science',
#   'date': '2022-01-07',
#   'explanation': "A male Adelie penguin performed this Ecstatic Vocalization in silhouette during the December 4 solar eclipse, the final eclipse of 2021. Of course his Ecstatic Vocalization is a special display that male penguins use to claim their territory and advertise their condition. This penguin's territory, at Cape Crozier Antarctica, is located in one of the largest Adelie penguin colonies. The colony has been studied by researchers for over 25 years. From there, last December's eclipse was about 80 percent total when seen at its maximum phase as the Moon's shadow crossed planet Earth's southernmost continent.   Status Updates: Deploying the James Webb Space Telescope",
#   'hdurl': 'https://apod.nasa.gov/apod/image/2201/eclipse_EV.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'Ecstatic Solar Eclipse',
#   'url': 'https://apod.nasa.gov/apod/image/2201/eclipse_EV1024.jpg'}]

# %% [markdown]
# Finally, let's grab the image url so that we can retrieve the actual image.

# %%
image_response = requests.get(response.json()[0]['url'])

# %% [markdown]
# For image responses, we don't want to look at the text or json, but instead take the content. We'll now use the `.content` attribute from the response to render an image.

# %%
from IPython.display import Image

# %%
Image(image_response.content)
